# %% [markdown]
# # Artifact 5
#
# ## Building off a simple scheduling problem
#
# I choose this problem because as the NHL season is coming to an end, I realized how much of an advantage it is to play teams in your conference later on in the season. As the season progresses, the standings can become very tight, especially within the conferences which directly determine playoff qualification and seeding. Playing against direct rivals towards the end of the season means that teams have greater control over their playoff destinies. Winning these games can directly impact their position in the standings or knock out close competitors.
#
# To be able to optimize the best schedule for each team to play teams in their conference later on I came up with a very simple example.
#
# Lets consider 4 teams
#
# a) Vancouver <br>
# b) Toronto <br>
# c) Boston <br>
# d) Chicago <br>
#
# Lets consider two divisions
# 1) Canadian Division
# 2) American Division
#
# For simplicity lets say you play each team in you division twice and the team in the other division once. hence each team should be playing 4 games. The team with most wins makes it to the championship.
#
# The objective is to maximize the team preferences
#
# Our decision is to decide which team play which each week
#
# Lets first write our constraints formally:
#
# $X_{VT1} + X_{VT2} + X_{VT3} + X_{VT4} = 2$ <br>
# $X_{BC1} + X_{BC2} + X_{BC3} + X_{BC4} = 2$ <br>
# $X_{VB1} + X_{VB2} + X_{VB3} + X_{VB4} = 1$ <br>
# $X_{VC1} + X_{VC2} + X_{VC3} + X_{VC4} = 1$ <br>
# $X_{TB1} + X_{TB2} + X_{TB3} + X_{TB4} = 1$ <br>
# $X_{TC1} + X_{TC2} + X_{TC3} + X_{TC4} = 1$ <br>
#
# The following constraint ensures that a team plays one game a week (in this case the first week)
# The same constraint needs to be set up for every week and every team <br>
# $X_{VC1} + X_{VT1} + X_{VB1} = 1$ <br>
#
# Now we need to assign preference scores. We know that the later in the season the more advantage there is for the teams playing in the same conference, hence lets assign preference scores as follows.
#
# If teams in the same conference play in the first week: score = 1 <br>
# If teams in the same conference play in the second week: score = 2 <br>
# If teams in the same conference play in the third week: score = 4 <br>
# If teams in the same conference play in the fourth week: score = 8 <br>
#
#
# This gives us the following objective function:
#
# $ maximize$ $x_{VT1} + 2x_{VT2} + 4x_{VT3} + 8x_{VT4} + x_{BC1} + 2x_{BC2} + 4x_{BC3} + 8x_{BC4} $
#
#
#
# Lets solve this using pulp

# %%
import pandas as pd
from itertools import permutations
import pulp as pl
import random

# %%
# Teams and divisions
teams = ['A', 'B', 'C', 'D']
divisions = {('A', 'B'), ('B', 'A'), ('C', 'D'), ('D', 'C')}
weeks = [1, 2, 3, 4]  # Weeks of the season

# Preference scores for intra-division matches
preference_scores = {1: 1, 2: 2, 3: 4, 4: 8}

# All possible matches, including intra-division matches twice and inter-division matches once
matches = [('A', 'B'), ('A', 'B'), ('C', 'D'), ('C', 'D'), ('A', 'C'), ('A', 'D'), ('B', 'C'), ('B', 'D')]

def valid_schedule(schedule):
    """ Check if a schedule is valid: each team plays exactly once per week """
    for week in schedule:
        teams_this_week = [team for match in week for team in match]
        if len(set(teams_this_week)) != 4:
            return False  # Some team appears more than once in a week or is missing
    return True

def generate_schedules():
    """ Generate all possible schedules of matches across 4 weeks """
    for potential_schedule in permutations(matches):
        # Split the flat permutation into weeks of 2 matches each
        schedule = [potential_schedule[i:i+2] for i in range(0, len(potential_schedule), 2)]
        if valid_schedule(schedule):
            yield schedule

def score_schedule(schedule):
    """ Calculate the preference score for a given schedule """
    score = 0
    for week_number, week_matches in enumerate(schedule, start=1):
        for match in week_matches:
            if match in divisions:
                score += preference_scores[week_number]
    return score

# Evaluate all valid schedules and find the one with the highest score
best_score = 0
best_schedule = None
for schedule in generate_schedules():
    score = score_schedule(schedule)
    if score > best_score:
        best_score = score
        best_schedule = schedule

# Print the best schedule and its score
if best_schedule:
    print("Best Schedule:")
    for week_index, week in enumerate(best_schedule, start=1):
        games = ", ".join(f"{match[0]} vs {match[1]}" for match in week)
        print(f"Week {week_index}: {games}")
    print("Total Preference Score:", best_score)
else:
    print("No valid schedule found.")
# Out:
# Best Schedule:
# Week 1: A vs C, B vs D
# Week 2: A vs D, B vs C
# Week 3: A vs B, C vs D
# Week 4: A vs B, C vs D
# Total Preference Score: 24

# %% [markdown]
# ## Same idea larger problem:
#
# I wanted to run a similar idea with more data using the same approach. I put my code into chat gpt and asked it to create code that makes this idea work on larger data. However I stop the run because it takes forever to run the code. I wasn't able to find a way to make it run faster so I took another approach for bigger set of teams.

# %%
from itertools import permutations

# Define teams and their conferences
eastern_conference = ['Boston Bruins', 'New York Rangers', 'Toronto Maple Leafs', 'Montreal Canadiens']
western_conference = ['Los Angeles Kings', 'San Jose Sharks', 'Chicago Blackhawks', 'Vegas Golden Knights']
teams = eastern_conference + western_conference

# Define intra-conference divisions
eastern_divisions = {(a, b) for a in eastern_conference for b in eastern_conference if a != b}
western_divisions = {(a, b) for a in western_conference for b in western_conference if a != b}
divisions = eastern_divisions.union(western_divisions)

# Number of weeks in the season
weeks = list(range(1, 9))  

# Preference scores for intra-conference matches
preference_scores = {week: 2**week for week in weeks}

# Generate all possible matches
matches = []
for i in teams:
    for j in teams:
        if i != j:
            matches.append((i, j))

def valid_schedule(schedule):
    """ Check if a schedule is valid: each team plays exactly once per week """
    for week in schedule:
        teams_this_week = [team for match in week for team in match]
        if len(set(teams_this_week)) != len(teams):
            return False  # Some team appears more than once in a week or is missing
    return True

def generate_schedules():
    """ Generate all possible schedules of matches across the season """
    for potential_schedule in permutations(matches, 4 * len(weeks)):  # 4 matches per week for 8 teams
        schedule = [potential_schedule[i:i+4] for i in range(0, len(potential_schedule), 4)]
        if valid_schedule(schedule):
            yield schedule

def score_schedule(schedule):
    """ Calculate the preference score for a given schedule """
    score = 0
    for week_number, week_matches in enumerate(schedule, start=1):
        for match in week_matches:
            if match in divisions:
                score += preference_scores[week_number]
    return score

# Evaluate all valid schedules and find the one with the highest score
best_score = 0
best_schedule = None
for schedule in generate_schedules():
    score = score_schedule(schedule)
    if score > best_score:
        best_score = score
        best_schedule = schedule

# Print the best schedule and its score
print("Best Schedule:")
for week_index, week in enumerate(best_schedule, start=1):
    games = ", ".join(f"{match[0]} vs {match[1]}" for match in week)
    print(f"Week {week_index}: {games}")
print("Total Preference Score:", best_score)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <module>
#      51 best_score = 0
#      52 best_schedule = None
# ---> 53 for schedule in generate_schedules():
#      54     score = score_schedule(schedule)
#      55     if score > best_score:
#
# Input In [11], in generate_schedules()
#      35 """ Generate all possible schedules of matches across the season """
#      36 for potential_schedule in permutations(matches, 4 * len(weeks)):  # 4 matches per week for 8 teams
# ---> 37     schedule = [potential_schedule[i:i+4] for i in range(0, len(potential_schedule), 4)]
#      38     if valid_schedule(schedule):
#      39         yield schedule
#
# Input In [11], in <listcomp>(.0)
#      35 """ Generate all possible schedules of matches across the season """
#      36 for potential_schedule in permutations(matches, 4 * len(weeks)):  # 4 matches per week for 8 teams
# ---> 37     schedule = [potential_schedule[i:i+4] for i in range(0, len(potential_schedule), 4)]
#      38     if valid_schedule(schedule):
#      39         yield schedule
#
# KeyboardInterrupt:

# %% [markdown]
# The run time on this is extremely long and the algorithm is very inefficient. I looked into how we can switch this algorithm into something that runs faster and can be used for every team in the NHL

# %% [markdown]
# ## Another way to optimize schedules that work better with big data
#
# Realistically I think it is hard to schedule based on when is best to play each team. Easier constraints would be the amount of rest between games and have a distance constraint between teams.
#
# I have set up this problem that is much easier to run.
#
# I take all the NHL teams in the league and split it based on their conference.
#
# I want to minimize the travel distance between all teams
#
# The constraints are as follows:
#
# Every team must play each team in the conference 4 times, 2 of those games must be away and 2 must be at home
# Every team must play every team in the other conference 2 times, 1 of those games must be away and 1 must be at home
#
# There must be a minimum of 3 days rest between games for every team
#
# Lets write this problem formally
#
# Our decision variable can be written as $X_{i, j, k}$ where the first index represents the home team, the second index represents the away team, and k represents the day index
#
# $X_{i, j, k} = 1$ if team i plays team j on day k
#
# Our objective function becomes:
#
# $
# minimize \sum_{i, j, k} d_{i, j} x_{j, i, k}
# $
#
#
# Our constraints are:
#
# 4 games between all teams in the same conference
# $
# \sum_{k} (x_{ijk} + x_{jik}) = 4$ for all i, j in same conference
#
#
#
# 2 games between all teams in the different conference
# $
# \sum_{k} (x_{ijk} + x_{jik}) = 2$ for all i, j in different conference
#
#
#
# ### Home and Away Constraints
# Each team must play half of its games at home and the other half away. The constraints differ based on whether the games are intra-conference or inter-conference.
#
# - **Intra-Conference Games**:
#   For all intra-conference pairs of teams \(i\) and \(j\), each team plays two games at home:
#   $
#   \sum_{k} x_{ijk} = 2
#   $
#
# - **Inter-Conference Games**:
#   For all inter-conference pairs of teams \(i\) and \(j\), each team plays one game at home:
#   $
#   \sum_{k} x_{ijk} = 1
#   $
#
# ### Rest Constraints
# To ensure adequate rest, there must be at least 3 days of rest between games for each team:
#
# $
# x_{ijk} + x_{i,j,k+1} + x_{i,j,k+2} + x_{i,j,k+3} \leq 1 \quad \text{for all } i, j, k
# $
#
# This constraint prevents any team from playing more than one game within a 3-day window.
#
# ### Schedule Feasibility
# A team cannot be in two places at once, which requires scheduling one game per team per day:
#
# - **Single Game per Team per Day**:
#   $
#   \sum_{j} x_{ijk} \leq 1 \quad \text{and} \quad \sum_{i} x_{ijk} \leq 1 \quad \text{for all } i, k
#   $
#
# This ensures that each team only has one game scheduled on any given day, whether as the home or away team.

# %%
# Team information (Conferences and Divisions)
eastern_teams = [
    "Tampa Bay Lightning", "Toronto Maple Leafs", "Boston Bruins", "Montreal Canadiens",
    "Florida Panthers", "Buffalo Sabres", "Detroit Red Wings", "Ottawa Senators",
    "New York Islanders", "New York Rangers", "New Jersey Devils", "Philadelphia Flyers",
    "Pittsburgh Penguins", "Washington Capitals", "Carolina Hurricanes", "Columbus Blue Jackets"
]
western_teams = [
    "Chicago Blackhawks", "St. Louis Blues", "Nashville Predators", "Minnesota Wild",
    "Dallas Stars", "Winnipeg Jets", "Colorado Avalanche", "Arizona Coyotes",
    "Edmonton Oilers", "Calgary Flames", "San Jose Sharks", "Los Angeles Kings",
    "Anaheim Ducks", "Vancouver Canucks", "Vegas Golden Knights", "Seattle Kraken"
]

teams = eastern_teams + western_teams
team_indices = {team: idx for idx, team in enumerate(teams)}

# Days in the season
days = list(range(200))

# Example of distances (in miles, approximations)
# Normally, you would use actual data here. This is a placeholder approach.
distances = {}
for team1 in teams:
    for team2 in teams:
        if team1 != team2:
            # Assign a random distance between 300 to 3000 miles
            distances[(team1, team2)] = random.randint(300, 3000)
# Problem
prob = pl.LpProblem("NHL_Travel_Minimization", pl.LpMinimize)

# Decision Variables
x = pl.LpVariable.dicts("match", (teams, teams, days), cat='Binary')

# Objective
prob += pl.lpSum(x[i][j][k] * distances[(i, j)] 
                 for i in teams for j in teams if i != j for k in days)

# Constraints
for i in teams:
    for j in teams:
        if i != j:
            conference_games = 4 if (i in eastern_teams and j in eastern_teams) or (i in western_teams and j in western_teams) else 2
            home_games = 2 if conference_games == 4 else 1
            # Match constraints
            prob += pl.lpSum(x[i][j][k] + x[j][i][k] for k in days) == conference_games
            # Home and away constraints
            prob += pl.lpSum(x[i][j][k] for k in days) == home_games
            
            # Rest constraints
            for k in days[:-3]:
                prob += x[i][j][k] + x[i][j][k+1] + x[i][j][k+2] + x[i][j][k+3] <= 1

# Solve Problem
prob.solve()

# Output results
for v in prob.variables():
    if v.varValue > 0:
        print(v.name, "=", v.varValue)
# Out:
# match_Anaheim_Ducks_Arizona_Coyotes_1 = 1.0
# match_Anaheim_Ducks_Arizona_Coyotes_100 = 1.0
# match_Anaheim_Ducks_Boston_Bruins_0 = 1.0
# match_Anaheim_Ducks_Buffalo_Sabres_1 = 1.0
# match_Anaheim_Ducks_Calgary_Flames_1 = 1.0
# match_Anaheim_Ducks_Calgary_Flames_100 = 1.0
# match_Anaheim_Ducks_Carolina_Hurricanes_0 = 1.0
# match_Anaheim_Ducks_Chicago_Blackhawks_1 = 1.0
# match_Anaheim_Ducks_Chicago_Blackhawks_10 = 1.0
# match_Anaheim_Ducks_Colorado_Avalanche_1 = 1.0
# match_Anaheim_Ducks_Colorado_Avalanche_100 = 1.0
# match_Anaheim_Ducks_Columbus_Blue_Jackets_0 = 1.0
# match_Anaheim_Ducks_Dallas_Stars_1 = 1.0
# match_Anaheim_Ducks_Dallas_Stars_100 = 1.0
# match_Anaheim_Ducks_Detroit_Red_Wings_1 = 1.0
# match_Anaheim_Ducks_Edmonton_Oilers_1 = 1.0
# match_Anaheim_Ducks_Edmonton_Oilers_10 = 1.0
# match_Anaheim_Ducks_Florida_Panthers_1 = 1.0
# match_Anaheim_Ducks_Los_Angeles_Kings_1 = 1.0
# match_Anaheim_Ducks_Los_Angeles_Kings_10 = 1.0
# match_Anaheim_Ducks_Minnesota_Wild_1 = 1.0
# match_Anaheim_Ducks_Minnesota_Wild_100 = 1.0
# match_Anaheim_Ducks_Montreal_Canadiens_0 = 1.0
# match_Anaheim_Ducks_Nashville_Predators_100 = 1.0
# match_Anaheim_Ducks_Nashville_Predators_14 = 1.0
# match_Anaheim_Ducks_New_Jersey_Devils_10 = 1.0
# match_Anaheim_Ducks_New_York_Islanders_0 = 1.0
# match_Anaheim_Ducks_New_York_Rangers_100 = 1.0
# match_Anaheim_Ducks_Ottawa_Senators_100 = 1.0
# match_Anaheim_Ducks_Philadelphia_Flyers_100 = 1.0
# match_Anaheim_Ducks_Pittsburgh_Penguins_0 = 1.0
# match_Anaheim_Ducks_San_Jose_Sharks_100 = 1.0
# match_Anaheim_Ducks_San_Jose_Sharks_8 = 1.0
# match_Anaheim_Ducks_Seattle_Kraken_100 = 1.0
# match_Anaheim_Ducks_Seattle_Kraken_14 = 1.0
# match_Anaheim_Ducks_St._Louis_Blues_100 = 1.0
# match_Anaheim_Ducks_St._Louis_Blues_14 = 1.0
# match_Anaheim_Ducks_Tampa_Bay_Lightning_100 = 1.0
# match_Anaheim_Ducks_Toronto_Maple_Leafs_10 = 1.0
# match_Anaheim_Ducks_Vancouver_Canucks_100 = 1.0
# match_Anaheim_Ducks_Vancouver_Canucks_14 = 1.0
# match_Anaheim_Ducks_Vegas_Golden_Knights_10 = 1.0
# match_Anaheim_Ducks_Vegas_Golden_Knights_14 = 1.0
# match_Anaheim_Ducks_Washington_Capitals_100 = 1.0
# match_Anaheim_Ducks_Winnipeg_Jets_100 = 1.0
# match_Anaheim_Ducks_Winnipeg_Jets_8 = 1.0
# match_Arizona_Coyotes_Anaheim_Ducks_100 = 1.0
# match_Arizona_Coyotes_Anaheim_Ducks_9 = 1.0
# match_Arizona_Coyotes_Boston_Bruins_1 = 1.0
# match_Arizona_Coyotes_Buffalo_Sabres_1 = 1.0
# match_Arizona_Coyotes_Calgary_Flames_1 = 1.0
# match_Arizona_Coyotes_Calgary_Flames_100 = 1.0
# match_Arizona_Coyotes_Carolina_Hurricanes_1 = 1.0
# match_Arizona_Coyotes_Chicago_Blackhawks_1 = 1.0
# match_Arizona_Coyotes_Chicago_Blackhawks_100 = 1.0
# match_Arizona_Coyotes_Colorado_Avalanche_1 = 1.0
# match_Arizona_Coyotes_Colorado_Avalanche_10 = 1.0
# match_Arizona_Coyotes_Columbus_Blue_Jackets_1 = 1.0
# match_Arizona_Coyotes_Dallas_Stars_1 = 1.0
# match_Arizona_Coyotes_Dallas_Stars_100 = 1.0
# match_Arizona_Coyotes_Detroit_Red_Wings_0 = 1.0
# match_Arizona_Coyotes_Edmonton_Oilers_1 = 1.0
# match_Arizona_Coyotes_Edmonton_Oilers_100 = 1.0
# match_Arizona_Coyotes_Florida_Panthers_1 = 1.0
# match_Arizona_Coyotes_Los_Angeles_Kings_1 = 1.0
# match_Arizona_Coyotes_Los_Angeles_Kings_10 = 1.0
# match_Arizona_Coyotes_Minnesota_Wild_1 = 1.0
# match_Arizona_Coyotes_Minnesota_Wild_100 = 1.0
# match_Arizona_Coyotes_Montreal_Canadiens_10 = 1.0
# match_Arizona_Coyotes_Nashville_Predators_0 = 1.0
# match_Arizona_Coyotes_Nashville_Predators_14 = 1.0
# match_Arizona_Coyotes_New_Jersey_Devils_0 = 1.0
# match_Arizona_Coyotes_New_York_Islanders_100 = 1.0
# match_Arizona_Coyotes_New_York_Rangers_100 = 1.0
# match_Arizona_Coyotes_Ottawa_Senators_100 = 1.0
# match_Arizona_Coyotes_Philadelphia_Flyers_0 = 1.0
# match_Arizona_Coyotes_Pittsburgh_Penguins_0 = 1.0
# match_Arizona_Coyotes_San_Jose_Sharks_100 = 1.0
# match_Arizona_Coyotes_San_Jose_Sharks_7 = 1.0
# match_Arizona_Coyotes_Seattle_Kraken_10 = 1.0
# match_Arizona_Coyotes_Seattle_Kraken_14 = 1.0
# match_Arizona_Coyotes_St._Louis_Blues_1 = 1.0
# match_Arizona_Coyotes_St._Louis_Blues_14 = 1.0
# match_Arizona_Coyotes_Tampa_Bay_Lightning_10 = 1.0
# match_Arizona_Coyotes_Toronto_Maple_Leafs_10 = 1.0
# match_Arizona_Coyotes_Vancouver_Canucks_14 = 1.0
# match_Arizona_Coyotes_Vancouver_Canucks_7 = 1.0
# match_Arizona_Coyotes_Vegas_Golden_Knights_100 = 1.0
# match_Arizona_Coyotes_Vegas_Golden_Knights_14 = 1.0
# match_Arizona_Coyotes_Washington_Capitals_0 = 1.0
# match_Arizona_Coyotes_Winnipeg_Jets_10 = 1.0
# match_Arizona_Coyotes_Winnipeg_Jets_14 = 1.0
# match_Boston_Bruins_Anaheim_Ducks_10 = 1.0
# match_Boston_Bruins_Arizona_Coyotes_0 = 1.0
# match_Boston_Bruins_Buffalo_Sabres_1 = 1.0
# match_Boston_Bruins_Buffalo_Sabres_100 = 1.0
# match_Boston_Bruins_Calgary_Flames_1 = 1.0
# match_Boston_Bruins_Carolina_Hurricanes_1 = 1.0
# match_Boston_Bruins_Carolina_Hurricanes_10 = 1.0
# match_Boston_Bruins_Chicago_Blackhawks_0 = 1.0
# match_Boston_Bruins_Colorado_Avalanche_0 = 1.0
# match_Boston_Bruins_Columbus_Blue_Jackets_1 = 1.0
# match_Boston_Bruins_Columbus_Blue_Jackets_10 = 1.0
# match_Boston_Bruins_Dallas_Stars_0 = 1.0
# match_Boston_Bruins_Detroit_Red_Wings_1 = 1.0
# match_Boston_Bruins_Detroit_Red_Wings_10 = 1.0
# match_Boston_Bruins_Edmonton_Oilers_0 = 1.0
# match_Boston_Bruins_Florida_Panthers_1 = 1.0
# match_Boston_Bruins_Florida_Panthers_100 = 1.0
# match_Boston_Bruins_Los_Angeles_Kings_0 = 1.0
# match_Boston_Bruins_Minnesota_Wild_1 = 1.0
# match_Boston_Bruins_Montreal_Canadiens_1 = 1.0
# match_Boston_Bruins_Montreal_Canadiens_14 = 1.0
# match_Boston_Bruins_Nashville_Predators_0 = 1.0
# match_Boston_Bruins_New_Jersey_Devils_100 = 1.0
# match_Boston_Bruins_New_Jersey_Devils_14 = 1.0
# match_Boston_Bruins_New_York_Islanders_100 = 1.0
# match_Boston_Bruins_New_York_Islanders_7 = 1.0
# match_Boston_Bruins_New_York_Rangers_10 = 1.0
# match_Boston_Bruins_New_York_Rangers_14 = 1.0
# match_Boston_Bruins_Ottawa_Senators_10 = 1.0
# match_Boston_Bruins_Ottawa_Senators_14 = 1.0
# match_Boston_Bruins_Philadelphia_Flyers_1 = 1.0
# match_Boston_Bruins_Philadelphia_Flyers_14 = 1.0
# match_Boston_Bruins_Pittsburgh_Penguins_100 = 1.0
# match_Boston_Bruins_Pittsburgh_Penguins_14 = 1.0
# match_Boston_Bruins_San_Jose_Sharks_0 = 1.0
# match_Boston_Bruins_Seattle_Kraken_100 = 1.0
# match_Boston_Bruins_St._Louis_Blues_0 = 1.0
# match_Boston_Bruins_Tampa_Bay_Lightning_10 = 1.0
# match_Boston_Bruins_Tampa_Bay_Lightning_14 = 1.0
# match_Boston_Bruins_Toronto_Maple_Leafs_100 = 1.0
# match_Boston_Bruins_Toronto_Maple_Leafs_14 = 1.0
# match_Boston_Bruins_Vancouver_Canucks_0 = 1.0
# match_Boston_Bruins_Vegas_Golden_Knights_10 = 1.0
# match_Boston_Bruins_Washington_Capitals_10 = 1.0
# match_Boston_Bruins_Washington_Capitals_14 = 1.0
# match_Boston_Bruins_Winnipeg_Jets_0 = 1.0
# match_Buffalo_Sabres_Anaheim_Ducks_10 = 1.0
# match_Buffalo_Sabres_Arizona_Coyotes_10 = 1.0
# match_Buffalo_Sabres_Boston_Bruins_14 = 1.0
# match_Buffalo_Sabres_Boston_Bruins_8 = 1.0
# match_Buffalo_Sabres_Calgary_Flames_0 = 1.0
# match_Buffalo_Sabres_Carolina_Hurricanes_1 = 1.0
# match_Buffalo_Sabres_Carolina_Hurricanes_100 = 1.0
# match_Buffalo_Sabres_Chicago_Blackhawks_1 = 1.0
# match_Buffalo_Sabres_Colorado_Avalanche_0 = 1.0
# match_Buffalo_Sabres_Columbus_Blue_Jackets_1 = 1.0
# match_Buffalo_Sabres_Columbus_Blue_Jackets_100 = 1.0
# match_Buffalo_Sabres_Dallas_Stars_0 = 1.0
# match_Buffalo_Sabres_Detroit_Red_Wings_1 = 1.0
# match_Buffalo_Sabres_Detroit_Red_Wings_10 = 1.0
# match_Buffalo_Sabres_Edmonton_Oilers_0 = 1.0
# match_Buffalo_Sabres_Florida_Panthers_1 = 1.0
# match_Buffalo_Sabres_Florida_Panthers_10 = 1.0
# match_Buffalo_Sabres_Los_Angeles_Kings_0 = 1.0
# match_Buffalo_Sabres_Minnesota_Wild_1 = 1.0
# match_Buffalo_Sabres_Montreal_Canadiens_14 = 1.0
# match_Buffalo_Sabres_Montreal_Canadiens_9 = 1.0
# match_Buffalo_Sabres_Nashville_Predators_100 = 1.0
# match_Buffalo_Sabres_New_Jersey_Devils_100 = 1.0
# match_Buffalo_Sabres_New_Jersey_Devils_9 = 1.0
# match_Buffalo_Sabres_New_York_Islanders_100 = 1.0
# match_Buffalo_Sabres_New_York_Islanders_7 = 1.0
# match_Buffalo_Sabres_New_York_Rangers_10 = 1.0
# match_Buffalo_Sabres_New_York_Rangers_14 = 1.0
# match_Buffalo_Sabres_Ottawa_Senators_100 = 1.0
# match_Buffalo_Sabres_Ottawa_Senators_14 = 1.0
# match_Buffalo_Sabres_Philadelphia_Flyers_10 = 1.0
# match_Buffalo_Sabres_Philadelphia_Flyers_14 = 1.0
# match_Buffalo_Sabres_Pittsburgh_Penguins_1 = 1.0
# match_Buffalo_Sabres_Pittsburgh_Penguins_14 = 1.0
# match_Buffalo_Sabres_San_Jose_Sharks_0 = 1.0
# match_Buffalo_Sabres_Seattle_Kraken_100 = 1.0
# match_Buffalo_Sabres_St._Louis_Blues_10 = 1.0
# match_Buffalo_Sabres_Tampa_Bay_Lightning_100 = 1.0
# match_Buffalo_Sabres_Tampa_Bay_Lightning_14 = 1.0
# match_Buffalo_Sabres_Toronto_Maple_Leafs_100 = 1.0
# match_Buffalo_Sabres_Toronto_Maple_Leafs_14 = 1.0
# match_Buffalo_Sabres_Vancouver_Canucks_100 = 1.0
# match_Buffalo_Sabres_Vegas_Golden_Knights_0 = 1.0
# match_Buffalo_Sabres_Washington_Capitals_100 = 1.0
# match_Buffalo_Sabres_Washington_Capitals_7 = 1.0
# match_Buffalo_Sabres_Winnipeg_Jets_100 = 1.0
# match_Calgary_Flames_Anaheim_Ducks_100 = 1.0
# match_Calgary_Flames_Anaheim_Ducks_9 = 1.0
# match_Calgary_Flames_Arizona_Coyotes_100 = 1.0
# match_Calgary_Flames_Arizona_Coyotes_8 = 1.0
# match_Calgary_Flames_Boston_Bruins_100 = 1.0
# match_Calgary_Flames_Buffalo_Sabres_10 = 1.0
# match_Calgary_Flames_Carolina_Hurricanes_0 = 1.0
# match_Calgary_Flames_Chicago_Blackhawks_1 = 1.0
# match_Calgary_Flames_Chicago_Blackhawks_10 = 1.0
# match_Calgary_Flames_Colorado_Avalanche_1 = 1.0
# match_Calgary_Flames_Colorado_Avalanche_100 = 1.0
# match_Calgary_Flames_Columbus_Blue_Jackets_0 = 1.0
# match_Calgary_Flames_Dallas_Stars_1 = 1.0
# match_Calgary_Flames_Dallas_Stars_100 = 1.0
# match_Calgary_Flames_Detroit_Red_Wings_1 = 1.0
# match_Calgary_Flames_Edmonton_Oilers_1 = 1.0
# match_Calgary_Flames_Edmonton_Oilers_10 = 1.0
# match_Calgary_Flames_Florida_Panthers_1 = 1.0
# match_Calgary_Flames_Los_Angeles_Kings_1 = 1.0
# match_Calgary_Flames_Los_Angeles_Kings_100 = 1.0
# match_Calgary_Flames_Minnesota_Wild_1 = 1.0
# match_Calgary_Flames_Minnesota_Wild_100 = 1.0
# match_Calgary_Flames_Montreal_Canadiens_0 = 1.0
# match_Calgary_Flames_Nashville_Predators_14 = 1.0
# match_Calgary_Flames_Nashville_Predators_9 = 1.0
# match_Calgary_Flames_New_Jersey_Devils_0 = 1.0
# match_Calgary_Flames_New_York_Islanders_0 = 1.0
# match_Calgary_Flames_New_York_Rangers_0 = 1.0
# match_Calgary_Flames_Ottawa_Senators_0 = 1.0
# match_Calgary_Flames_Philadelphia_Flyers_100 = 1.0
# match_Calgary_Flames_Pittsburgh_Penguins_10 = 1.0
# match_Calgary_Flames_San_Jose_Sharks_14 = 1.0
# match_Calgary_Flames_San_Jose_Sharks_7 = 1.0
# match_Calgary_Flames_Seattle_Kraken_100 = 1.0
# match_Calgary_Flames_Seattle_Kraken_14 = 1.0
# match_Calgary_Flames_St._Louis_Blues_14 = 1.0
# match_Calgary_Flames_St._Louis_Blues_8 = 1.0
# match_Calgary_Flames_Tampa_Bay_Lightning_0 = 1.0
# match_Calgary_Flames_Toronto_Maple_Leafs_100 = 1.0
# match_Calgary_Flames_Vancouver_Canucks_14 = 1.0
# match_Calgary_Flames_Vancouver_Canucks_7 = 1.0
# match_Calgary_Flames_Vegas_Golden_Knights_100 = 1.0
# match_Calgary_Flames_Vegas_Golden_Knights_14 = 1.0
# match_Calgary_Flames_Washington_Capitals_10 = 1.0
# match_Calgary_Flames_Winnipeg_Jets_10 = 1.0
# match_Calgary_Flames_Winnipeg_Jets_14 = 1.0
# match_Carolina_Hurricanes_Anaheim_Ducks_100 = 1.0
# match_Carolina_Hurricanes_Arizona_Coyotes_10 = 1.0
# match_Carolina_Hurricanes_Boston_Bruins_100 = 1.0
# match_Carolina_Hurricanes_Boston_Bruins_14 = 1.0
# match_Carolina_Hurricanes_Buffalo_Sabres_14 = 1.0
# match_Carolina_Hurricanes_Buffalo_Sabres_8 = 1.0
# match_Carolina_Hurricanes_Calgary_Flames_100 = 1.0
# match_Carolina_Hurricanes_Chicago_Blackhawks_1 = 1.0
# match_Carolina_Hurricanes_Colorado_Avalanche_0 = 1.0
# match_Carolina_Hurricanes_Columbus_Blue_Jackets_1 = 1.0
# match_Carolina_Hurricanes_Columbus_Blue_Jackets_10 = 1.0
# match_Carolina_Hurricanes_Dallas_Stars_0 = 1.0
# match_Carolina_Hurricanes_Detroit_Red_Wings_1 = 1.0
# match_Carolina_Hurricanes_Detroit_Red_Wings_100 = 1.0
# match_Carolina_Hurricanes_Edmonton_Oilers_0 = 1.0
# match_Carolina_Hurricanes_Florida_Panthers_1 = 1.0
# match_Carolina_Hurricanes_Florida_Panthers_100 = 1.0
# match_Carolina_Hurricanes_Los_Angeles_Kings_0 = 1.0
# match_Carolina_Hurricanes_Minnesota_Wild_1 = 1.0
# match_Carolina_Hurricanes_Montreal_Canadiens_100 = 1.0
# match_Carolina_Hurricanes_Montreal_Canadiens_14 = 1.0
# match_Carolina_Hurricanes_Nashville_Predators_10 = 1.0
# match_Carolina_Hurricanes_New_Jersey_Devils_100 = 1.0
# match_Carolina_Hurricanes_New_Jersey_Devils_14 = 1.0
# match_Carolina_Hurricanes_New_York_Islanders_100 = 1.0
# match_Carolina_Hurricanes_New_York_Islanders_14 = 1.0
# match_Carolina_Hurricanes_New_York_Rangers_100 = 1.0
# match_Carolina_Hurricanes_New_York_Rangers_14 = 1.0
# match_Carolina_Hurricanes_Ottawa_Senators_1 = 1.0
# match_Carolina_Hurricanes_Ottawa_Senators_14 = 1.0
# match_Carolina_Hurricanes_Philadelphia_Flyers_100 = 1.0
# match_Carolina_Hurricanes_Philadelphia_Flyers_8 = 1.0
# match_Carolina_Hurricanes_Pittsburgh_Penguins_14 = 1.0
# match_Carolina_Hurricanes_Pittsburgh_Penguins_8 = 1.0
# match_Carolina_Hurricanes_San_Jose_Sharks_10 = 1.0
# match_Carolina_Hurricanes_Seattle_Kraken_100 = 1.0
# match_Carolina_Hurricanes_St._Louis_Blues_0 = 1.0
# match_Carolina_Hurricanes_Tampa_Bay_Lightning_10 = 1.0
# match_Carolina_Hurricanes_Tampa_Bay_Lightning_14 = 1.0
# match_Carolina_Hurricanes_Toronto_Maple_Leafs_100 = 1.0
# match_Carolina_Hurricanes_Toronto_Maple_Leafs_14 = 1.0
# match_Carolina_Hurricanes_Vancouver_Canucks_100 = 1.0
# match_Carolina_Hurricanes_Vegas_Golden_Knights_0 = 1.0
# match_Carolina_Hurricanes_Washington_Capitals_14 = 1.0
# match_Carolina_Hurricanes_Washington_Capitals_8 = 1.0
# match_Carolina_Hurricanes_Winnipeg_Jets_10 = 1.0
# match_Chicago_Blackhawks_Anaheim_Ducks_100 = 1.0
# match_Chicago_Blackhawks_Anaheim_Ducks_14 = 1.0
# match_Chicago_Blackhawks_Arizona_Coyotes_1 = 1.0
# match_Chicago_Blackhawks_Arizona_Coyotes_14 = 1.0
# match_Chicago_Blackhawks_Boston_Bruins_100 = 1.0
# match_Chicago_Blackhawks_Buffalo_Sabres_100 = 1.0
# match_Chicago_Blackhawks_Calgary_Flames_10 = 1.0
# match_Chicago_Blackhawks_Calgary_Flames_14 = 1.0
# match_Chicago_Blackhawks_Carolina_Hurricanes_0 = 1.0
# match_Chicago_Blackhawks_Colorado_Avalanche_1 = 1.0
# match_Chicago_Blackhawks_Colorado_Avalanche_100 = 1.0
# match_Chicago_Blackhawks_Columbus_Blue_Jackets_1 = 1.0
# match_Chicago_Blackhawks_Dallas_Stars_1 = 1.0
# match_Chicago_Blackhawks_Dallas_Stars_100 = 1.0
# match_Chicago_Blackhawks_Detroit_Red_Wings_1 = 1.0
# match_Chicago_Blackhawks_Edmonton_Oilers_1 = 1.0
# match_Chicago_Blackhawks_Edmonton_Oilers_100 = 1.0
# match_Chicago_Blackhawks_Florida_Panthers_1 = 1.0
# match_Chicago_Blackhawks_Los_Angeles_Kings_1 = 1.0
# match_Chicago_Blackhawks_Los_Angeles_Kings_10 = 1.0
# match_Chicago_Blackhawks_Minnesota_Wild_1 = 1.0
# match_Chicago_Blackhawks_Minnesota_Wild_100 = 1.0
# match_Chicago_Blackhawks_Montreal_Canadiens_100 = 1.0
# match_Chicago_Blackhawks_Nashville_Predators_0 = 1.0
# match_Chicago_Blackhawks_Nashville_Predators_14 = 1.0
# match_Chicago_Blackhawks_New_Jersey_Devils_100 = 1.0
# match_Chicago_Blackhawks_New_York_Islanders_10 = 1.0
# match_Chicago_Blackhawks_New_York_Rangers_10 = 1.0
# match_Chicago_Blackhawks_Ottawa_Senators_10 = 1.0
# match_Chicago_Blackhawks_Philadelphia_Flyers_10 = 1.0
# match_Chicago_Blackhawks_Pittsburgh_Penguins_100 = 1.0
# match_Chicago_Blackhawks_San_Jose_Sharks_100 = 1.0
# match_Chicago_Blackhawks_San_Jose_Sharks_14 = 1.0
# match_Chicago_Blackhawks_Seattle_Kraken_0 = 1.0
# match_Chicago_Blackhawks_Seattle_Kraken_14 = 1.0
# match_Chicago_Blackhawks_St._Louis_Blues_100 = 1.0
# match_Chicago_Blackhawks_St._Louis_Blues_7 = 1.0
# match_Chicago_Blackhawks_Tampa_Bay_Lightning_0 = 1.0
# match_Chicago_Blackhawks_Toronto_Maple_Leafs_0 = 1.0
# match_Chicago_Blackhawks_Vancouver_Canucks_14 = 1.0
# match_Chicago_Blackhawks_Vancouver_Canucks_7 = 1.0
# match_Chicago_Blackhawks_Vegas_Golden_Knights_100 = 1.0
# match_Chicago_Blackhawks_Vegas_Golden_Knights_14 = 1.0
# match_Chicago_Blackhawks_Washington_Capitals_10 = 1.0
# match_Chicago_Blackhawks_Winnipeg_Jets_100 = 1.0
# match_Chicago_Blackhawks_Winnipeg_Jets_7 = 1.0
# match_Colorado_Avalanche_Anaheim_Ducks_100 = 1.0
# match_Colorado_Avalanche_Anaheim_Ducks_14 = 1.0
# match_Colorado_Avalanche_Arizona_Coyotes_100 = 1.0
# match_Colorado_Avalanche_Arizona_Coyotes_8 = 1.0
# match_Colorado_Avalanche_Boston_Bruins_100 = 1.0
# match_Colorado_Avalanche_Buffalo_Sabres_0 = 1.0
# match_Colorado_Avalanche_Calgary_Flames_14 = 1.0
# match_Colorado_Avalanche_Calgary_Flames_9 = 1.0
# match_Colorado_Avalanche_Carolina_Hurricanes_100 = 1.0
# match_Colorado_Avalanche_Chicago_Blackhawks_0 = 1.0
# match_Colorado_Avalanche_Chicago_Blackhawks_14 = 1.0
# match_Colorado_Avalanche_Columbus_Blue_Jackets_1 = 1.0
# match_Colorado_Avalanche_Dallas_Stars_1 = 1.0
# match_Colorado_Avalanche_Dallas_Stars_100 = 1.0
# match_Colorado_Avalanche_Detroit_Red_Wings_1 = 1.0
# match_Colorado_Avalanche_Edmonton_Oilers_1 = 1.0
# match_Colorado_Avalanche_Edmonton_Oilers_100 = 1.0
# match_Colorado_Avalanche_Florida_Panthers_0 = 1.0
# match_Colorado_Avalanche_Los_Angeles_Kings_1 = 1.0
# match_Colorado_Avalanche_Los_Angeles_Kings_100 = 1.0
# match_Colorado_Avalanche_Minnesota_Wild_1 = 1.0
# match_Colorado_Avalanche_Minnesota_Wild_10 = 1.0
# match_Colorado_Avalanche_Montreal_Canadiens_0 = 1.0
# match_Colorado_Avalanche_Nashville_Predators_100 = 1.0
# match_Colorado_Avalanche_Nashville_Predators_9 = 1.0
# match_Colorado_Avalanche_New_Jersey_Devils_10 = 1.0
# match_Colorado_Avalanche_New_York_Islanders_10 = 1.0
# match_Colorado_Avalanche_New_York_Rangers_100 = 1.0
# match_Colorado_Avalanche_Ottawa_Senators_100 = 1.0
# match_Colorado_Avalanche_Philadelphia_Flyers_100 = 1.0
# match_Colorado_Avalanche_Pittsburgh_Penguins_0 = 1.0
# match_Colorado_Avalanche_San_Jose_Sharks_100 = 1.0
# match_Colorado_Avalanche_San_Jose_Sharks_14 = 1.0
# match_Colorado_Avalanche_Seattle_Kraken_14 = 1.0
# match_Colorado_Avalanche_Seattle_Kraken_7 = 1.0
# match_Colorado_Avalanche_St._Louis_Blues_0 = 1.0
# match_Colorado_Avalanche_St._Louis_Blues_14 = 1.0
# match_Colorado_Avalanche_Tampa_Bay_Lightning_0 = 1.0
# match_Colorado_Avalanche_Toronto_Maple_Leafs_10 = 1.0
# match_Colorado_Avalanche_Vancouver_Canucks_100 = 1.0
# match_Colorado_Avalanche_Vancouver_Canucks_14 = 1.0
# match_Colorado_Avalanche_Vegas_Golden_Knights_100 = 1.0
# match_Colorado_Avalanche_Vegas_Golden_Knights_7 = 1.0
# match_Colorado_Avalanche_Washington_Capitals_100 = 1.0
# match_Colorado_Avalanche_Winnipeg_Jets_100 = 1.0
# match_Colorado_Avalanche_Winnipeg_Jets_14 = 1.0
# match_Columbus_Blue_Jackets_Anaheim_Ducks_0 = 1.0
# match_Columbus_Blue_Jackets_Arizona_Coyotes_0 = 1.0
# match_Columbus_Blue_Jackets_Boston_Bruins_14 = 1.0
# match_Columbus_Blue_Jackets_Boston_Bruins_8 = 1.0
# match_Columbus_Blue_Jackets_Buffalo_Sabres_100 = 1.0
# match_Columbus_Blue_Jackets_Buffalo_Sabres_14 = 1.0
# match_Columbus_Blue_Jackets_Calgary_Flames_10 = 1.0
# match_Columbus_Blue_Jackets_Carolina_Hurricanes_14 = 1.0
# match_Columbus_Blue_Jackets_Carolina_Hurricanes_8 = 1.0
# match_Columbus_Blue_Jackets_Chicago_Blackhawks_0 = 1.0
# match_Columbus_Blue_Jackets_Colorado_Avalanche_100 = 1.0
# match_Columbus_Blue_Jackets_Dallas_Stars_1 = 1.0
# match_Columbus_Blue_Jackets_Detroit_Red_Wings_1 = 1.0
# match_Columbus_Blue_Jackets_Detroit_Red_Wings_100 = 1.0
# match_Columbus_Blue_Jackets_Edmonton_Oilers_0 = 1.0
# match_Columbus_Blue_Jackets_Florida_Panthers_1 = 1.0
# match_Columbus_Blue_Jackets_Florida_Panthers_100 = 1.0
# match_Columbus_Blue_Jackets_Los_Angeles_Kings_0 = 1.0
# match_Columbus_Blue_Jackets_Minnesota_Wild_0 = 1.0
# match_Columbus_Blue_Jackets_Montreal_Canadiens_100 = 1.0
# match_Columbus_Blue_Jackets_Montreal_Canadiens_9 = 1.0
# match_Columbus_Blue_Jackets_Nashville_Predators_10 = 1.0
# match_Columbus_Blue_Jackets_New_Jersey_Devils_100 = 1.0
# match_Columbus_Blue_Jackets_New_Jersey_Devils_14 = 1.0
# match_Columbus_Blue_Jackets_New_York_Islanders_10 = 1.0
# match_Columbus_Blue_Jackets_New_York_Islanders_14 = 1.0
# match_Columbus_Blue_Jackets_New_York_Rangers_100 = 1.0
# match_Columbus_Blue_Jackets_New_York_Rangers_14 = 1.0
# match_Columbus_Blue_Jackets_Ottawa_Senators_100 = 1.0
# match_Columbus_Blue_Jackets_Ottawa_Senators_8 = 1.0
# match_Columbus_Blue_Jackets_Philadelphia_Flyers_14 = 1.0
# match_Columbus_Blue_Jackets_Philadelphia_Flyers_8 = 1.0
# match_Columbus_Blue_Jackets_Pittsburgh_Penguins_100 = 1.0
# match_Columbus_Blue_Jackets_Pittsburgh_Penguins_14 = 1.0
# match_Columbus_Blue_Jackets_San_Jose_Sharks_100 = 1.0
# match_Columbus_Blue_Jackets_Seattle_Kraken_100 = 1.0
# match_Columbus_Blue_Jackets_St._Louis_Blues_100 = 1.0
# match_Columbus_Blue_Jackets_Tampa_Bay_Lightning_100 = 1.0
# match_Columbus_Blue_Jackets_Tampa_Bay_Lightning_14 = 1.0
# match_Columbus_Blue_Jackets_Toronto_Maple_Leafs_14 = 1.0
# match_Columbus_Blue_Jackets_Toronto_Maple_Leafs_8 = 1.0
# match_Columbus_Blue_Jackets_Vancouver_Canucks_0 = 1.0
# match_Columbus_Blue_Jackets_Vegas_Golden_Knights_100 = 1.0
# match_Columbus_Blue_Jackets_Washington_Capitals_100 = 1.0
# match_Columbus_Blue_Jackets_Washington_Capitals_8 = 1.0
# match_Columbus_Blue_Jackets_Winnipeg_Jets_0 = 1.0
# match_Dallas_Stars_Anaheim_Ducks_14 = 1.0
# match_Dallas_Stars_Anaheim_Ducks_9 = 1.0
# match_Dallas_Stars_Arizona_Coyotes_100 = 1.0
# match_Dallas_Stars_Arizona_Coyotes_14 = 1.0
# match_Dallas_Stars_Boston_Bruins_100 = 1.0
# match_Dallas_Stars_Buffalo_Sabres_10 = 1.0
# match_Dallas_Stars_Calgary_Flames_0 = 1.0
# match_Dallas_Stars_Calgary_Flames_14 = 1.0
# match_Dallas_Stars_Carolina_Hurricanes_100 = 1.0
# match_Dallas_Stars_Chicago_Blackhawks_0 = 1.0
# match_Dallas_Stars_Chicago_Blackhawks_14 = 1.0
# match_Dallas_Stars_Colorado_Avalanche_100 = 1.0
# match_Dallas_Stars_Colorado_Avalanche_14 = 1.0
# match_Dallas_Stars_Columbus_Blue_Jackets_100 = 1.0
# match_Dallas_Stars_Detroit_Red_Wings_1 = 1.0
# match_Dallas_Stars_Edmonton_Oilers_1 = 1.0
# match_Dallas_Stars_Edmonton_Oilers_100 = 1.0
# match_Dallas_Stars_Florida_Panthers_0 = 1.0
# match_Dallas_Stars_Los_Angeles_Kings_1 = 1.0
# match_Dallas_Stars_Los_Angeles_Kings_10 = 1.0
# match_Dallas_Stars_Minnesota_Wild_1 = 1.0
# match_Dallas_Stars_Minnesota_Wild_100 = 1.0
# match_Dallas_Stars_Montreal_Canadiens_100 = 1.0
# match_Dallas_Stars_Nashville_Predators_100 = 1.0
# match_Dallas_Stars_Nashville_Predators_14 = 1.0
# match_Dallas_Stars_New_Jersey_Devils_100 = 1.0
# match_Dallas_Stars_New_York_Islanders_10 = 1.0
# match_Dallas_Stars_New_York_Rangers_10 = 1.0
# match_Dallas_Stars_Ottawa_Senators_0 = 1.0
# match_Dallas_Stars_Philadelphia_Flyers_100 = 1.0
# match_Dallas_Stars_Pittsburgh_Penguins_100 = 1.0
# match_Dallas_Stars_San_Jose_Sharks_0 = 1.0
# match_Dallas_Stars_San_Jose_Sharks_14 = 1.0
# match_Dallas_Stars_Seattle_Kraken_1 = 1.0
# match_Dallas_Stars_Seattle_Kraken_14 = 1.0
# match_Dallas_Stars_St._Louis_Blues_100 = 1.0
# match_Dallas_Stars_St._Louis_Blues_14 = 1.0
# match_Dallas_Stars_Tampa_Bay_Lightning_100 = 1.0
# match_Dallas_Stars_Toronto_Maple_Leafs_0 = 1.0
# match_Dallas_Stars_Vancouver_Canucks_1 = 1.0
# match_Dallas_Stars_Vancouver_Canucks_14 = 1.0
# match_Dallas_Stars_Vegas_Golden_Knights_0 = 1.0
# match_Dallas_Stars_Vegas_Golden_Knights_14 = 1.0
# match_Dallas_Stars_Washington_Capitals_10 = 1.0
# match_Dallas_Stars_Winnipeg_Jets_14 = 1.0
# match_Dallas_Stars_Winnipeg_Jets_7 = 1.0
# match_Detroit_Red_Wings_Anaheim_Ducks_10 = 1.0
# match_Detroit_Red_Wings_Arizona_Coyotes_100 = 1.0
# match_Detroit_Red_Wings_Boston_Bruins_10 = 1.0
# match_Detroit_Red_Wings_Boston_Bruins_14 = 1.0
# match_Detroit_Red_Wings_Buffalo_Sabres_100 = 1.0
# match_Detroit_Red_Wings_Buffalo_Sabres_8 = 1.0
# match_Detroit_Red_Wings_Calgary_Flames_0 = 1.0
# match_Detroit_Red_Wings_Carolina_Hurricanes_1 = 1.0
# match_Detroit_Red_Wings_Carolina_Hurricanes_14 = 1.0
# match_Detroit_Red_Wings_Chicago_Blackhawks_10 = 1.0
# match_Detroit_Red_Wings_Colorado_Avalanche_10 = 1.0
# match_Detroit_Red_Wings_Columbus_Blue_Jackets_100 = 1.0
# match_Detroit_Red_Wings_Columbus_Blue_Jackets_14 = 1.0
# match_Detroit_Red_Wings_Dallas_Stars_10 = 1.0
# match_Detroit_Red_Wings_Edmonton_Oilers_0 = 1.0
# match_Detroit_Red_Wings_Florida_Panthers_1 = 1.0
# match_Detroit_Red_Wings_Florida_Panthers_10 = 1.0
# match_Detroit_Red_Wings_Los_Angeles_Kings_0 = 1.0
# match_Detroit_Red_Wings_Minnesota_Wild_0 = 1.0
# match_Detroit_Red_Wings_Montreal_Canadiens_100 = 1.0
# match_Detroit_Red_Wings_Montreal_Canadiens_14 = 1.0
# match_Detroit_Red_Wings_Nashville_Predators_100 = 1.0
# match_Detroit_Red_Wings_New_Jersey_Devils_10 = 1.0
# match_Detroit_Red_Wings_New_Jersey_Devils_14 = 1.0
# match_Detroit_Red_Wings_New_York_Islanders_10 = 1.0
# match_Detroit_Red_Wings_New_York_Islanders_14 = 1.0
# match_Detroit_Red_Wings_New_York_Rangers_0 = 1.0
# match_Detroit_Red_Wings_New_York_Rangers_14 = 1.0
# match_Detroit_Red_Wings_Ottawa_Senators_100 = 1.0
# match_Detroit_Red_Wings_Ottawa_Senators_7 = 1.0
# match_Detroit_Red_Wings_Philadelphia_Flyers_100 = 1.0
# match_Detroit_Red_Wings_Philadelphia_Flyers_14 = 1.0
# match_Detroit_Red_Wings_Pittsburgh_Penguins_100 = 1.0
# match_Detroit_Red_Wings_Pittsburgh_Penguins_7 = 1.0
# match_Detroit_Red_Wings_San_Jose_Sharks_10 = 1.0
# match_Detroit_Red_Wings_Seattle_Kraken_100 = 1.0
# match_Detroit_Red_Wings_St._Louis_Blues_0 = 1.0
# match_Detroit_Red_Wings_Tampa_Bay_Lightning_100 = 1.0
# match_Detroit_Red_Wings_Tampa_Bay_Lightning_8 = 1.0
# match_Detroit_Red_Wings_Toronto_Maple_Leafs_14 = 1.0
# match_Detroit_Red_Wings_Toronto_Maple_Leafs_8 = 1.0
# match_Detroit_Red_Wings_Vancouver_Canucks_10 = 1.0
# match_Detroit_Red_Wings_Vegas_Golden_Knights_100 = 1.0
# match_Detroit_Red_Wings_Washington_Capitals_100 = 1.0
# match_Detroit_Red_Wings_Washington_Capitals_14 = 1.0
# match_Detroit_Red_Wings_Winnipeg_Jets_100 = 1.0
# match_Edmonton_Oilers_Anaheim_Ducks_10 = 1.0
# match_Edmonton_Oilers_Anaheim_Ducks_14 = 1.0
# match_Edmonton_Oilers_Arizona_Coyotes_100 = 1.0
# match_Edmonton_Oilers_Arizona_Coyotes_8 = 1.0
# match_Edmonton_Oilers_Boston_Bruins_100 = 1.0
# match_Edmonton_Oilers_Buffalo_Sabres_10 = 1.0
# match_Edmonton_Oilers_Calgary_Flames_100 = 1.0
# match_Edmonton_Oilers_Calgary_Flames_9 = 1.0
# match_Edmonton_Oilers_Carolina_Hurricanes_0 = 1.0
# match_Edmonton_Oilers_Chicago_Blackhawks_100 = 1.0
# match_Edmonton_Oilers_Chicago_Blackhawks_14 = 1.0
# match_Edmonton_Oilers_Colorado_Avalanche_14 = 1.0
# match_Edmonton_Oilers_Colorado_Avalanche_8 = 1.0
# match_Edmonton_Oilers_Columbus_Blue_Jackets_10 = 1.0
# match_Edmonton_Oilers_Dallas_Stars_10 = 1.0
# match_Edmonton_Oilers_Dallas_Stars_14 = 1.0
# match_Edmonton_Oilers_Detroit_Red_Wings_10 = 1.0
# match_Edmonton_Oilers_Florida_Panthers_0 = 1.0
# match_Edmonton_Oilers_Los_Angeles_Kings_1 = 1.0
# match_Edmonton_Oilers_Los_Angeles_Kings_10 = 1.0
# match_Edmonton_Oilers_Minnesota_Wild_1 = 1.0
# match_Edmonton_Oilers_Minnesota_Wild_100 = 1.0
# match_Edmonton_Oilers_Montreal_Canadiens_10 = 1.0
# match_Edmonton_Oilers_Nashville_Predators_100 = 1.0
# match_Edmonton_Oilers_Nashville_Predators_9 = 1.0
# match_Edmonton_Oilers_New_Jersey_Devils_0 = 1.0
# match_Edmonton_Oilers_New_York_Islanders_100 = 1.0
# match_Edmonton_Oilers_New_York_Rangers_100 = 1.0
# match_Edmonton_Oilers_Ottawa_Senators_10 = 1.0
# match_Edmonton_Oilers_Philadelphia_Flyers_0 = 1.0
# match_Edmonton_Oilers_Pittsburgh_Penguins_100 = 1.0
# match_Edmonton_Oilers_San_Jose_Sharks_100 = 1.0
# match_Edmonton_Oilers_San_Jose_Sharks_14 = 1.0
# match_Edmonton_Oilers_Seattle_Kraken_100 = 1.0
# match_Edmonton_Oilers_Seattle_Kraken_14 = 1.0
# match_Edmonton_Oilers_St._Louis_Blues_100 = 1.0
# match_Edmonton_Oilers_St._Louis_Blues_14 = 1.0
# match_Edmonton_Oilers_Tampa_Bay_Lightning_10 = 1.0
# match_Edmonton_Oilers_Toronto_Maple_Leafs_100 = 1.0
# match_Edmonton_Oilers_Vancouver_Canucks_100 = 1.0
# match_Edmonton_Oilers_Vancouver_Canucks_14 = 1.0
# match_Edmonton_Oilers_Vegas_Golden_Knights_100 = 1.0
# match_Edmonton_Oilers_Vegas_Golden_Knights_7 = 1.0
# match_Edmonton_Oilers_Washington_Capitals_10 = 1.0
# match_Edmonton_Oilers_Winnipeg_Jets_100 = 1.0
# match_Edmonton_Oilers_Winnipeg_Jets_14 = 1.0
# match_Florida_Panthers_Anaheim_Ducks_10 = 1.0
# match_Florida_Panthers_Arizona_Coyotes_0 = 1.0
# match_Florida_Panthers_Boston_Bruins_1 = 1.0
# match_Florida_Panthers_Boston_Bruins_14 = 1.0
# match_Florida_Panthers_Buffalo_Sabres_0 = 1.0
# match_Florida_Panthers_Buffalo_Sabres_14 = 1.0
# match_Florida_Panthers_Calgary_Flames_0 = 1.0
# match_Florida_Panthers_Carolina_Hurricanes_10 = 1.0
# match_Florida_Panthers_Carolina_Hurricanes_14 = 1.0
# match_Florida_Panthers_Chicago_Blackhawks_100 = 1.0
# match_Florida_Panthers_Colorado_Avalanche_100 = 1.0
# match_Florida_Panthers_Columbus_Blue_Jackets_100 = 1.0
# match_Florida_Panthers_Columbus_Blue_Jackets_14 = 1.0
# match_Florida_Panthers_Dallas_Stars_0 = 1.0
# match_Florida_Panthers_Detroit_Red_Wings_0 = 1.0
# match_Florida_Panthers_Detroit_Red_Wings_14 = 1.0
# match_Florida_Panthers_Edmonton_Oilers_0 = 1.0
# match_Florida_Panthers_Los_Angeles_Kings_0 = 1.0
# match_Florida_Panthers_Minnesota_Wild_0 = 1.0
# match_Florida_Panthers_Montreal_Canadiens_100 = 1.0
# match_Florida_Panthers_Montreal_Canadiens_14 = 1.0
# match_Florida_Panthers_Nashville_Predators_100 = 1.0
# match_Florida_Panthers_New_Jersey_Devils_0 = 1.0
# match_Florida_Panthers_New_Jersey_Devils_14 = 1.0
# match_Florida_Panthers_New_York_Islanders_100 = 1.0
# match_Florida_Panthers_New_York_Islanders_7 = 1.0
# match_Florida_Panthers_New_York_Rangers_1 = 1.0
# match_Florida_Panthers_New_York_Rangers_14 = 1.0
# match_Florida_Panthers_Ottawa_Senators_14 = 1.0
# match_Florida_Panthers_Ottawa_Senators_7 = 1.0
# match_Florida_Panthers_Philadelphia_Flyers_100 = 1.0
# match_Florida_Panthers_Philadelphia_Flyers_14 = 1.0
# match_Florida_Panthers_Pittsburgh_Penguins_100 = 1.0
# match_Florida_Panthers_Pittsburgh_Penguins_14 = 1.0
# match_Florida_Panthers_San_Jose_Sharks_100 = 1.0
# match_Florida_Panthers_Seattle_Kraken_100 = 1.0
# match_Florida_Panthers_St._Louis_Blues_100 = 1.0
# match_Florida_Panthers_Tampa_Bay_Lightning_100 = 1.0
# match_Florida_Panthers_Tampa_Bay_Lightning_14 = 1.0
# match_Florida_Panthers_Toronto_Maple_Leafs_14 = 1.0
# match_Florida_Panthers_Toronto_Maple_Leafs_8 = 1.0
# match_Florida_Panthers_Vancouver_Canucks_0 = 1.0
# match_Florida_Panthers_Vegas_Golden_Knights_100 = 1.0
# match_Florida_Panthers_Washington_Capitals_100 = 1.0
# match_Florida_Panthers_Washington_Capitals_7 = 1.0
# match_Florida_Panthers_Winnipeg_Jets_0 = 1.0
# match_Los_Angeles_Kings_Anaheim_Ducks_1 = 1.0
# match_Los_Angeles_Kings_Anaheim_Ducks_14 = 1.0
# match_Los_Angeles_Kings_Arizona_Coyotes_100 = 1.0
# match_Los_Angeles_Kings_Arizona_Coyotes_8 = 1.0
# match_Los_Angeles_Kings_Boston_Bruins_0 = 1.0
# match_Los_Angeles_Kings_Buffalo_Sabres_100 = 1.0
# match_Los_Angeles_Kings_Calgary_Flames_10 = 1.0
# match_Los_Angeles_Kings_Calgary_Flames_14 = 1.0
# match_Los_Angeles_Kings_Carolina_Hurricanes_0 = 1.0
# match_Los_Angeles_Kings_Chicago_Blackhawks_100 = 1.0
# match_Los_Angeles_Kings_Chicago_Blackhawks_14 = 1.0
# match_Los_Angeles_Kings_Colorado_Avalanche_14 = 1.0
# match_Los_Angeles_Kings_Colorado_Avalanche_8 = 1.0
# match_Los_Angeles_Kings_Columbus_Blue_Jackets_0 = 1.0
# match_Los_Angeles_Kings_Dallas_Stars_100 = 1.0
# match_Los_Angeles_Kings_Dallas_Stars_8 = 1.0
# match_Los_Angeles_Kings_Detroit_Red_Wings_0 = 1.0
# match_Los_Angeles_Kings_Edmonton_Oilers_100 = 1.0
# match_Los_Angeles_Kings_Edmonton_Oilers_14 = 1.0
# match_Los_Angeles_Kings_Florida_Panthers_10 = 1.0
# match_Los_Angeles_Kings_Minnesota_Wild_0 = 1.0
# match_Los_Angeles_Kings_Minnesota_Wild_100 = 1.0
# match_Los_Angeles_Kings_Montreal_Canadiens_100 = 1.0
# match_Los_Angeles_Kings_Nashville_Predators_100 = 1.0
# match_Los_Angeles_Kings_Nashville_Predators_14 = 1.0
# match_Los_Angeles_Kings_New_Jersey_Devils_0 = 1.0
# match_Los_Angeles_Kings_New_York_Islanders_100 = 1.0
# match_Los_Angeles_Kings_New_York_Rangers_100 = 1.0
# match_Los_Angeles_Kings_Ottawa_Senators_10 = 1.0
# match_Los_Angeles_Kings_Philadelphia_Flyers_100 = 1.0
# match_Los_Angeles_Kings_Pittsburgh_Penguins_100 = 1.0
# match_Los_Angeles_Kings_San_Jose_Sharks_100 = 1.0
# match_Los_Angeles_Kings_San_Jose_Sharks_14 = 1.0
# match_Los_Angeles_Kings_Seattle_Kraken_14 = 1.0
# match_Los_Angeles_Kings_Seattle_Kraken_7 = 1.0
# match_Los_Angeles_Kings_St._Louis_Blues_14 = 1.0
# match_Los_Angeles_Kings_St._Louis_Blues_8 = 1.0
# match_Los_Angeles_Kings_Tampa_Bay_Lightning_0 = 1.0
# match_Los_Angeles_Kings_Toronto_Maple_Leafs_10 = 1.0
# match_Los_Angeles_Kings_Vancouver_Canucks_10 = 1.0
# match_Los_Angeles_Kings_Vancouver_Canucks_14 = 1.0
# match_Los_Angeles_Kings_Vegas_Golden_Knights_14 = 1.0
# match_Los_Angeles_Kings_Vegas_Golden_Knights_7 = 1.0
# match_Los_Angeles_Kings_Washington_Capitals_100 = 1.0
# match_Los_Angeles_Kings_Winnipeg_Jets_100 = 1.0
# match_Los_Angeles_Kings_Winnipeg_Jets_14 = 1.0
# match_Minnesota_Wild_Anaheim_Ducks_100 = 1.0
# match_Minnesota_Wild_Anaheim_Ducks_9 = 1.0
# match_Minnesota_Wild_Arizona_Coyotes_100 = 1.0
# match_Minnesota_Wild_Arizona_Coyotes_14 = 1.0
# match_Minnesota_Wild_Boston_Bruins_0 = 1.0
# match_Minnesota_Wild_Buffalo_Sabres_100 = 1.0
# match_Minnesota_Wild_Calgary_Flames_10 = 1.0
# match_Minnesota_Wild_Calgary_Flames_14 = 1.0
# match_Minnesota_Wild_Carolina_Hurricanes_10 = 1.0
# match_Minnesota_Wild_Chicago_Blackhawks_14 = 1.0
# match_Minnesota_Wild_Chicago_Blackhawks_8 = 1.0
# match_Minnesota_Wild_Colorado_Avalanche_10 = 1.0
# match_Minnesota_Wild_Colorado_Avalanche_14 = 1.0
# match_Minnesota_Wild_Columbus_Blue_Jackets_0 = 1.0
# match_Minnesota_Wild_Dallas_Stars_10 = 1.0
# match_Minnesota_Wild_Dallas_Stars_14 = 1.0
# match_Minnesota_Wild_Detroit_Red_Wings_100 = 1.0
# match_Minnesota_Wild_Edmonton_Oilers_0 = 1.0
# match_Minnesota_Wild_Edmonton_Oilers_14 = 1.0
# match_Minnesota_Wild_Florida_Panthers_10 = 1.0
# match_Minnesota_Wild_Los_Angeles_Kings_124 = 1.0
# match_Minnesota_Wild_Los_Angeles_Kings_128 = 1.0
# match_Minnesota_Wild_Montreal_Canadiens_0 = 1.0
# match_Minnesota_Wild_Nashville_Predators_1 = 1.0
# match_Minnesota_Wild_Nashville_Predators_100 = 1.0
# match_Minnesota_Wild_New_Jersey_Devils_1 = 1.0
# match_Minnesota_Wild_New_York_Islanders_1 = 1.0
# match_Minnesota_Wild_New_York_Rangers_1 = 1.0
# match_Minnesota_Wild_Ottawa_Senators_1 = 1.0
# match_Minnesota_Wild_Philadelphia_Flyers_0 = 1.0
# match_Minnesota_Wild_Pittsburgh_Penguins_1 = 1.0
# match_Minnesota_Wild_San_Jose_Sharks_1 = 1.0
# match_Minnesota_Wild_San_Jose_Sharks_100 = 1.0
# match_Minnesota_Wild_Seattle_Kraken_1 = 1.0
# match_Minnesota_Wild_Seattle_Kraken_100 = 1.0
# match_Minnesota_Wild_St._Louis_Blues_1 = 1.0
# match_Minnesota_Wild_St._Louis_Blues_100 = 1.0
# match_Minnesota_Wild_Tampa_Bay_Lightning_1 = 1.0
# match_Minnesota_Wild_Toronto_Maple_Leafs_0 = 1.0
# match_Minnesota_Wild_Vancouver_Canucks_1 = 1.0
# match_Minnesota_Wild_Vancouver_Canucks_100 = 1.0
# match_Minnesota_Wild_Vegas_Golden_Knights_1 = 1.0
# match_Minnesota_Wild_Vegas_Golden_Knights_100 = 1.0
# match_Minnesota_Wild_Washington_Capitals_0 = 1.0
# match_Minnesota_Wild_Winnipeg_Jets_1 = 1.0
# match_Minnesota_Wild_Winnipeg_Jets_100 = 1.0
# match_Montreal_Canadiens_Anaheim_Ducks_1 = 1.0
# match_Montreal_Canadiens_Arizona_Coyotes_1 = 1.0
# match_Montreal_Canadiens_Boston_Bruins_1 = 1.0
# match_Montreal_Canadiens_Boston_Bruins_10 = 1.0
# match_Montreal_Canadiens_Buffalo_Sabres_1 = 1.0
# match_Montreal_Canadiens_Buffalo_Sabres_100 = 1.0
# match_Montreal_Canadiens_Calgary_Flames_0 = 1.0
# match_Montreal_Canadiens_Carolina_Hurricanes_1 = 1.0
# match_Montreal_Canadiens_Carolina_Hurricanes_10 = 1.0
# match_Montreal_Canadiens_Chicago_Blackhawks_0 = 1.0
# match_Montreal_Canadiens_Colorado_Avalanche_1 = 1.0
# match_Montreal_Canadiens_Columbus_Blue_Jackets_1 = 1.0
# match_Montreal_Canadiens_Columbus_Blue_Jackets_10 = 1.0
# match_Montreal_Canadiens_Dallas_Stars_0 = 1.0
# match_Montreal_Canadiens_Detroit_Red_Wings_1 = 1.0
# match_Montreal_Canadiens_Detroit_Red_Wings_100 = 1.0
# match_Montreal_Canadiens_Edmonton_Oilers_0 = 1.0
# match_Montreal_Canadiens_Florida_Panthers_1 = 1.0
# match_Montreal_Canadiens_Florida_Panthers_10 = 1.0
# match_Montreal_Canadiens_Los_Angeles_Kings_1 = 1.0
# match_Montreal_Canadiens_Minnesota_Wild_100 = 1.0
# match_Montreal_Canadiens_Nashville_Predators_0 = 1.0
# match_Montreal_Canadiens_New_Jersey_Devils_1 = 1.0
# match_Montreal_Canadiens_New_Jersey_Devils_100 = 1.0
# match_Montreal_Canadiens_New_York_Islanders_1 = 1.0
# match_Montreal_Canadiens_New_York_Islanders_10 = 1.0
# match_Montreal_Canadiens_New_York_Rangers_1 = 1.0
# match_Montreal_Canadiens_New_York_Rangers_100 = 1.0
# match_Montreal_Canadiens_Ottawa_Senators_1 = 1.0
# match_Montreal_Canadiens_Ottawa_Senators_10 = 1.0
# match_Montreal_Canadiens_Philadelphia_Flyers_1 = 1.0
# match_Montreal_Canadiens_Philadelphia_Flyers_10 = 1.0
# match_Montreal_Canadiens_Pittsburgh_Penguins_1 = 1.0
# match_Montreal_Canadiens_Pittsburgh_Penguins_10 = 1.0
# match_Montreal_Canadiens_San_Jose_Sharks_1 = 1.0
# match_Montreal_Canadiens_Seattle_Kraken_0 = 1.0
# match_Montreal_Canadiens_St._Louis_Blues_0 = 1.0
# match_Montreal_Canadiens_Tampa_Bay_Lightning_1 = 1.0
# match_Montreal_Canadiens_Tampa_Bay_Lightning_10 = 1.0
# match_Montreal_Canadiens_Toronto_Maple_Leafs_1 = 1.0
# match_Montreal_Canadiens_Toronto_Maple_Leafs_100 = 1.0
# match_Montreal_Canadiens_Vancouver_Canucks_0 = 1.0
# match_Montreal_Canadiens_Vegas_Golden_Knights_0 = 1.0
# match_Montreal_Canadiens_Washington_Capitals_1 = 1.0
# match_Montreal_Canadiens_Washington_Capitals_10 = 1.0
# match_Montreal_Canadiens_Winnipeg_Jets_0 = 1.0
# match_Nashville_Predators_Anaheim_Ducks_1 = 1.0
# match_Nashville_Predators_Anaheim_Ducks_100 = 1.0
# match_Nashville_Predators_Arizona_Coyotes_1 = 1.0
# match_Nashville_Predators_Arizona_Coyotes_100 = 1.0
# match_Nashville_Predators_Boston_Bruins_1 = 1.0
# match_Nashville_Predators_Buffalo_Sabres_0 = 1.0
# match_Nashville_Predators_Calgary_Flames_1 = 1.0
# match_Nashville_Predators_Calgary_Flames_10 = 1.0
# match_Nashville_Predators_Carolina_Hurricanes_1 = 1.0
# match_Nashville_Predators_Chicago_Blackhawks_1 = 1.0
# match_Nashville_Predators_Chicago_Blackhawks_100 = 1.0
# match_Nashville_Predators_Colorado_Avalanche_1 = 1.0
# match_Nashville_Predators_Colorado_Avalanche_10 = 1.0
# match_Nashville_Predators_Columbus_Blue_Jackets_0 = 1.0
# match_Nashville_Predators_Dallas_Stars_1 = 1.0
# match_Nashville_Predators_Dallas_Stars_10 = 1.0
# match_Nashville_Predators_Detroit_Red_Wings_0 = 1.0
# match_Nashville_Predators_Edmonton_Oilers_1 = 1.0
# match_Nashville_Predators_Edmonton_Oilers_100 = 1.0
# match_Nashville_Predators_Florida_Panthers_1 = 1.0
# match_Nashville_Predators_Los_Angeles_Kings_1 = 1.0
# match_Nashville_Predators_Los_Angeles_Kings_10 = 1.0
# match_Nashville_Predators_Minnesota_Wild_0 = 1.0
# match_Nashville_Predators_Minnesota_Wild_14 = 1.0
# match_Nashville_Predators_Montreal_Canadiens_0 = 1.0
# match_Nashville_Predators_New_Jersey_Devils_1 = 1.0
# match_Nashville_Predators_New_York_Islanders_1 = 1.0
# match_Nashville_Predators_New_York_Rangers_0 = 1.0
# match_Nashville_Predators_Ottawa_Senators_0 = 1.0
# match_Nashville_Predators_Philadelphia_Flyers_0 = 1.0
# match_Nashville_Predators_Pittsburgh_Penguins_1 = 1.0
# match_Nashville_Predators_San_Jose_Sharks_1 = 1.0
# match_Nashville_Predators_San_Jose_Sharks_10 = 1.0
# match_Nashville_Predators_Seattle_Kraken_1 = 1.0
# match_Nashville_Predators_Seattle_Kraken_10 = 1.0
# match_Nashville_Predators_St._Louis_Blues_1 = 1.0
# match_Nashville_Predators_St._Louis_Blues_100 = 1.0
# match_Nashville_Predators_Tampa_Bay_Lightning_0 = 1.0
# match_Nashville_Predators_Toronto_Maple_Leafs_0 = 1.0
# match_Nashville_Predators_Vancouver_Canucks_1 = 1.0
# match_Nashville_Predators_Vancouver_Canucks_10 = 1.0
# match_Nashville_Predators_Vegas_Golden_Knights_1 = 1.0
# match_Nashville_Predators_Vegas_Golden_Knights_10 = 1.0
# match_Nashville_Predators_Washington_Capitals_1 = 1.0
# match_Nashville_Predators_Winnipeg_Jets_1 = 1.0
# match_Nashville_Predators_Winnipeg_Jets_100 = 1.0
# match_New_Jersey_Devils_Anaheim_Ducks_1 = 1.0
# match_New_Jersey_Devils_Arizona_Coyotes_0 = 1.0
# match_New_Jersey_Devils_Boston_Bruins_1 = 1.0
# match_New_Jersey_Devils_Boston_Bruins_10 = 1.0
# match_New_Jersey_Devils_Buffalo_Sabres_1 = 1.0
# match_New_Jersey_Devils_Buffalo_Sabres_10 = 1.0
# match_New_Jersey_Devils_Calgary_Flames_1 = 1.0
# match_New_Jersey_Devils_Carolina_Hurricanes_1 = 1.0
# match_New_Jersey_Devils_Carolina_Hurricanes_10 = 1.0
# match_New_Jersey_Devils_Chicago_Blackhawks_1 = 1.0
# match_New_Jersey_Devils_Colorado_Avalanche_0 = 1.0
# match_New_Jersey_Devils_Columbus_Blue_Jackets_1 = 1.0
# match_New_Jersey_Devils_Columbus_Blue_Jackets_10 = 1.0
# match_New_Jersey_Devils_Dallas_Stars_0 = 1.0
# match_New_Jersey_Devils_Detroit_Red_Wings_1 = 1.0
# match_New_Jersey_Devils_Detroit_Red_Wings_100 = 1.0
# match_New_Jersey_Devils_Edmonton_Oilers_0 = 1.0
# match_New_Jersey_Devils_Florida_Panthers_1 = 1.0
# match_New_Jersey_Devils_Florida_Panthers_100 = 1.0
# match_New_Jersey_Devils_Los_Angeles_Kings_0 = 1.0
# match_New_Jersey_Devils_Minnesota_Wild_100 = 1.0
# match_New_Jersey_Devils_Montreal_Canadiens_100 = 1.0
# match_New_Jersey_Devils_Montreal_Canadiens_8 = 1.0
# match_New_Jersey_Devils_Nashville_Predators_100 = 1.0
# match_New_Jersey_Devils_New_York_Islanders_1 = 1.0
# match_New_Jersey_Devils_New_York_Islanders_100 = 1.0
# match_New_Jersey_Devils_New_York_Rangers_1 = 1.0
# match_New_Jersey_Devils_New_York_Rangers_100 = 1.0
# match_New_Jersey_Devils_Ottawa_Senators_1 = 1.0
# match_New_Jersey_Devils_Ottawa_Senators_100 = 1.0
# match_New_Jersey_Devils_Philadelphia_Flyers_1 = 1.0
# match_New_Jersey_Devils_Philadelphia_Flyers_100 = 1.0
# match_New_Jersey_Devils_Pittsburgh_Penguins_1 = 1.0
# match_New_Jersey_Devils_Pittsburgh_Penguins_10 = 1.0
# match_New_Jersey_Devils_San_Jose_Sharks_1 = 1.0
# match_New_Jersey_Devils_Seattle_Kraken_0 = 1.0
# match_New_Jersey_Devils_St._Louis_Blues_1 = 1.0
# match_New_Jersey_Devils_Tampa_Bay_Lightning_1 = 1.0
# match_New_Jersey_Devils_Tampa_Bay_Lightning_100 = 1.0
# match_New_Jersey_Devils_Toronto_Maple_Leafs_1 = 1.0
# match_New_Jersey_Devils_Toronto_Maple_Leafs_100 = 1.0
# match_New_Jersey_Devils_Vancouver_Canucks_0 = 1.0
# match_New_Jersey_Devils_Vegas_Golden_Knights_0 = 1.0
# match_New_Jersey_Devils_Washington_Capitals_1 = 1.0
# match_New_Jersey_Devils_Washington_Capitals_10 = 1.0
# match_New_Jersey_Devils_Winnipeg_Jets_0 = 1.0
# match_New_York_Islanders_Anaheim_Ducks_0 = 1.0
# match_New_York_Islanders_Arizona_Coyotes_0 = 1.0
# match_New_York_Islanders_Boston_Bruins_1 = 1.0
# match_New_York_Islanders_Boston_Bruins_100 = 1.0
# match_New_York_Islanders_Buffalo_Sabres_1 = 1.0
# match_New_York_Islanders_Buffalo_Sabres_100 = 1.0
# match_New_York_Islanders_Calgary_Flames_1 = 1.0
# match_New_York_Islanders_Carolina_Hurricanes_1 = 1.0
# match_New_York_Islanders_Carolina_Hurricanes_10 = 1.0
# match_New_York_Islanders_Chicago_Blackhawks_1 = 1.0
# match_New_York_Islanders_Colorado_Avalanche_1 = 1.0
# match_New_York_Islanders_Columbus_Blue_Jackets_1 = 1.0
# match_New_York_Islanders_Columbus_Blue_Jackets_10 = 1.0
# match_New_York_Islanders_Dallas_Stars_1 = 1.0
# match_New_York_Islanders_Detroit_Red_Wings_1 = 1.0
# match_New_York_Islanders_Detroit_Red_Wings_10 = 1.0
# match_New_York_Islanders_Edmonton_Oilers_0 = 1.0
# match_New_York_Islanders_Florida_Panthers_1 = 1.0
# match_New_York_Islanders_Florida_Panthers_100 = 1.0
# match_New_York_Islanders_Los_Angeles_Kings_1 = 1.0
# match_New_York_Islanders_Minnesota_Wild_100 = 1.0
# match_New_York_Islanders_Montreal_Canadiens_100 = 1.0
# match_New_York_Islanders_Montreal_Canadiens_14 = 1.0
# match_New_York_Islanders_Nashville_Predators_100 = 1.0
# match_New_York_Islanders_New_Jersey_Devils_10 = 1.0
# match_New_York_Islanders_New_Jersey_Devils_14 = 1.0
# match_New_York_Islanders_New_York_Rangers_1 = 1.0
# match_New_York_Islanders_New_York_Rangers_100 = 1.0
# match_New_York_Islanders_Ottawa_Senators_1 = 1.0
# match_New_York_Islanders_Ottawa_Senators_10 = 1.0
# match_New_York_Islanders_Philadelphia_Flyers_1 = 1.0
# match_New_York_Islanders_Philadelphia_Flyers_10 = 1.0
# match_New_York_Islanders_Pittsburgh_Penguins_1 = 1.0
# match_New_York_Islanders_Pittsburgh_Penguins_10 = 1.0
# match_New_York_Islanders_San_Jose_Sharks_0 = 1.0
# match_New_York_Islanders_Seattle_Kraken_1 = 1.0
# match_New_York_Islanders_St._Louis_Blues_1 = 1.0
# match_New_York_Islanders_Tampa_Bay_Lightning_1 = 1.0
# match_New_York_Islanders_Tampa_Bay_Lightning_10 = 1.0
# match_New_York_Islanders_Toronto_Maple_Leafs_1 = 1.0
# match_New_York_Islanders_Toronto_Maple_Leafs_10 = 1.0
# match_New_York_Islanders_Vancouver_Canucks_1 = 1.0
# match_New_York_Islanders_Vegas_Golden_Knights_0 = 1.0
# match_New_York_Islanders_Washington_Capitals_1 = 1.0
# match_New_York_Islanders_Washington_Capitals_100 = 1.0
# match_New_York_Islanders_Winnipeg_Jets_1 = 1.0
# match_New_York_Rangers_Anaheim_Ducks_0 = 1.0
# match_New_York_Rangers_Arizona_Coyotes_1 = 1.0
# match_New_York_Rangers_Boston_Bruins_1 = 1.0
# match_New_York_Rangers_Boston_Bruins_100 = 1.0
# match_New_York_Rangers_Buffalo_Sabres_1 = 1.0
# match_New_York_Rangers_Buffalo_Sabres_100 = 1.0
# match_New_York_Rangers_Calgary_Flames_0 = 1.0
# match_New_York_Rangers_Carolina_Hurricanes_1 = 1.0
# match_New_York_Rangers_Carolina_Hurricanes_100 = 1.0
# match_New_York_Rangers_Chicago_Blackhawks_0 = 1.0
# match_New_York_Rangers_Colorado_Avalanche_0 = 1.0
# match_New_York_Rangers_Columbus_Blue_Jackets_1 = 1.0
# match_New_York_Rangers_Columbus_Blue_Jackets_100 = 1.0
# match_New_York_Rangers_Dallas_Stars_0 = 1.0
# match_New_York_Rangers_Detroit_Red_Wings_1 = 1.0
# match_New_York_Rangers_Detroit_Red_Wings_100 = 1.0
# match_New_York_Rangers_Edmonton_Oilers_0 = 1.0
# match_New_York_Rangers_Florida_Panthers_1 = 1.0
# match_New_York_Rangers_Florida_Panthers_100 = 1.0
# match_New_York_Rangers_Los_Angeles_Kings_0 = 1.0
# match_New_York_Rangers_Minnesota_Wild_100 = 1.0
# match_New_York_Rangers_Montreal_Canadiens_100 = 1.0
# match_New_York_Rangers_Montreal_Canadiens_14 = 1.0
# match_New_York_Rangers_Nashville_Predators_10 = 1.0
# match_New_York_Rangers_New_Jersey_Devils_100 = 1.0
# match_New_York_Rangers_New_Jersey_Devils_9 = 1.0
# match_New_York_Rangers_New_York_Islanders_10 = 1.0
# match_New_York_Rangers_New_York_Islanders_14 = 1.0
# match_New_York_Rangers_Ottawa_Senators_1 = 1.0
# match_New_York_Rangers_Ottawa_Senators_100 = 1.0
# match_New_York_Rangers_Philadelphia_Flyers_1 = 1.0
# match_New_York_Rangers_Philadelphia_Flyers_100 = 1.0
# match_New_York_Rangers_Pittsburgh_Penguins_1 = 1.0
# match_New_York_Rangers_Pittsburgh_Penguins_100 = 1.0
# match_New_York_Rangers_San_Jose_Sharks_0 = 1.0
# match_New_York_Rangers_Seattle_Kraken_0 = 1.0
# match_New_York_Rangers_St._Louis_Blues_1 = 1.0
# match_New_York_Rangers_Tampa_Bay_Lightning_1 = 1.0
# match_New_York_Rangers_Tampa_Bay_Lightning_100 = 1.0
# match_New_York_Rangers_Toronto_Maple_Leafs_1 = 1.0
# match_New_York_Rangers_Toronto_Maple_Leafs_100 = 1.0
# match_New_York_Rangers_Vancouver_Canucks_1 = 1.0
# match_New_York_Rangers_Vegas_Golden_Knights_1 = 1.0
# match_New_York_Rangers_Washington_Capitals_1 = 1.0
# match_New_York_Rangers_Washington_Capitals_10 = 1.0
# match_New_York_Rangers_Winnipeg_Jets_1 = 1.0
# match_Ottawa_Senators_Anaheim_Ducks_0 = 1.0
# match_Ottawa_Senators_Arizona_Coyotes_1 = 1.0
# match_Ottawa_Senators_Boston_Bruins_1 = 1.0
# match_Ottawa_Senators_Boston_Bruins_10 = 1.0
# match_Ottawa_Senators_Buffalo_Sabres_1 = 1.0
# match_Ottawa_Senators_Buffalo_Sabres_100 = 1.0
# match_Ottawa_Senators_Calgary_Flames_0 = 1.0
# match_Ottawa_Senators_Carolina_Hurricanes_1 = 1.0
# match_Ottawa_Senators_Carolina_Hurricanes_100 = 1.0
# match_Ottawa_Senators_Chicago_Blackhawks_0 = 1.0
# match_Ottawa_Senators_Colorado_Avalanche_1 = 1.0
# match_Ottawa_Senators_Columbus_Blue_Jackets_1 = 1.0
# match_Ottawa_Senators_Columbus_Blue_Jackets_10 = 1.0
# match_Ottawa_Senators_Dallas_Stars_0 = 1.0
# match_Ottawa_Senators_Detroit_Red_Wings_1 = 1.0
# match_Ottawa_Senators_Detroit_Red_Wings_100 = 1.0
# match_Ottawa_Senators_Edmonton_Oilers_0 = 1.0
# match_Ottawa_Senators_Florida_Panthers_1 = 1.0
# match_Ottawa_Senators_Florida_Panthers_100 = 1.0
# match_Ottawa_Senators_Los_Angeles_Kings_0 = 1.0
# match_Ottawa_Senators_Minnesota_Wild_100 = 1.0
# match_Ottawa_Senators_Montreal_Canadiens_10 = 1.0
# match_Ottawa_Senators_Montreal_Canadiens_14 = 1.0
# match_Ottawa_Senators_Nashville_Predators_10 = 1.0
# match_Ottawa_Senators_New_Jersey_Devils_100 = 1.0
# match_Ottawa_Senators_New_Jersey_Devils_14 = 1.0
# match_Ottawa_Senators_New_York_Islanders_14 = 1.0
# match_Ottawa_Senators_New_York_Islanders_9 = 1.0
# match_Ottawa_Senators_New_York_Rangers_100 = 1.0
# match_Ottawa_Senators_New_York_Rangers_8 = 1.0
# match_Ottawa_Senators_Philadelphia_Flyers_1 = 1.0
# match_Ottawa_Senators_Philadelphia_Flyers_100 = 1.0
# match_Ottawa_Senators_Pittsburgh_Penguins_1 = 1.0
# match_Ottawa_Senators_Pittsburgh_Penguins_100 = 1.0
# match_Ottawa_Senators_San_Jose_Sharks_1 = 1.0
# match_Ottawa_Senators_Seattle_Kraken_1 = 1.0
# match_Ottawa_Senators_St._Louis_Blues_1 = 1.0
# match_Ottawa_Senators_Tampa_Bay_Lightning_1 = 1.0
# match_Ottawa_Senators_Tampa_Bay_Lightning_100 = 1.0
# match_Ottawa_Senators_Toronto_Maple_Leafs_1 = 1.0
# match_Ottawa_Senators_Toronto_Maple_Leafs_10 = 1.0
# match_Ottawa_Senators_Vancouver_Canucks_0 = 1.0
# match_Ottawa_Senators_Vegas_Golden_Knights_0 = 1.0
# match_Ottawa_Senators_Washington_Capitals_1 = 1.0
# match_Ottawa_Senators_Washington_Capitals_100 = 1.0
# match_Ottawa_Senators_Winnipeg_Jets_1 = 1.0
# match_Philadelphia_Flyers_Anaheim_Ducks_0 = 1.0
# match_Philadelphia_Flyers_Arizona_Coyotes_1 = 1.0
# match_Philadelphia_Flyers_Boston_Bruins_1 = 1.0
# ...
# match_St._Louis_Blues_Calgary_Flames_100 = 1.0
# match_St._Louis_Blues_Carolina_Hurricanes_0 = 1.0
# match_St._Louis_Blues_Chicago_Blackhawks_1 = 1.0
# match_St._Louis_Blues_Chicago_Blackhawks_10 = 1.0
# match_St._Louis_Blues_Colorado_Avalanche_1 = 1.0
# match_St._Louis_Blues_Colorado_Avalanche_100 = 1.0
# match_St._Louis_Blues_Columbus_Blue_Jackets_0 = 1.0
# match_St._Louis_Blues_Dallas_Stars_1 = 1.0
# match_St._Louis_Blues_Dallas_Stars_100 = 1.0
# match_St._Louis_Blues_Detroit_Red_Wings_1 = 1.0
# match_St._Louis_Blues_Edmonton_Oilers_1 = 1.0
# match_St._Louis_Blues_Edmonton_Oilers_100 = 1.0
# match_St._Louis_Blues_Florida_Panthers_0 = 1.0
# match_St._Louis_Blues_Los_Angeles_Kings_1 = 1.0
# match_St._Louis_Blues_Los_Angeles_Kings_100 = 1.0
# match_St._Louis_Blues_Minnesota_Wild_100 = 1.0
# match_St._Louis_Blues_Minnesota_Wild_14 = 1.0
# match_St._Louis_Blues_Montreal_Canadiens_0 = 1.0
# match_St._Louis_Blues_Nashville_Predators_100 = 1.0
# match_St._Louis_Blues_Nashville_Predators_9 = 1.0
# match_St._Louis_Blues_New_Jersey_Devils_10 = 1.0
# match_St._Louis_Blues_New_York_Islanders_100 = 1.0
# match_St._Louis_Blues_New_York_Rangers_0 = 1.0
# match_St._Louis_Blues_Ottawa_Senators_10 = 1.0
# match_St._Louis_Blues_Philadelphia_Flyers_100 = 1.0
# match_St._Louis_Blues_Pittsburgh_Penguins_0 = 1.0
# match_St._Louis_Blues_San_Jose_Sharks_10 = 1.0
# match_St._Louis_Blues_San_Jose_Sharks_14 = 1.0
# match_St._Louis_Blues_Seattle_Kraken_100 = 1.0
# match_St._Louis_Blues_Seattle_Kraken_14 = 1.0
# match_St._Louis_Blues_Tampa_Bay_Lightning_1 = 1.0
# match_St._Louis_Blues_Toronto_Maple_Leafs_1 = 1.0
# match_St._Louis_Blues_Vancouver_Canucks_1 = 1.0
# match_St._Louis_Blues_Vancouver_Canucks_100 = 1.0
# match_St._Louis_Blues_Vegas_Golden_Knights_1 = 1.0
# match_St._Louis_Blues_Vegas_Golden_Knights_10 = 1.0
# match_St._Louis_Blues_Washington_Capitals_1 = 1.0
# match_St._Louis_Blues_Winnipeg_Jets_1 = 1.0
# match_St._Louis_Blues_Winnipeg_Jets_100 = 1.0
# match_Tampa_Bay_Lightning_Anaheim_Ducks_1 = 1.0
# match_Tampa_Bay_Lightning_Arizona_Coyotes_0 = 1.0
# match_Tampa_Bay_Lightning_Boston_Bruins_1 = 1.0
# match_Tampa_Bay_Lightning_Boston_Bruins_10 = 1.0
# match_Tampa_Bay_Lightning_Buffalo_Sabres_1 = 1.0
# match_Tampa_Bay_Lightning_Buffalo_Sabres_100 = 1.0
# match_Tampa_Bay_Lightning_Calgary_Flames_0 = 1.0
# match_Tampa_Bay_Lightning_Carolina_Hurricanes_1 = 1.0
# match_Tampa_Bay_Lightning_Carolina_Hurricanes_100 = 1.0
# match_Tampa_Bay_Lightning_Chicago_Blackhawks_1 = 1.0
# match_Tampa_Bay_Lightning_Colorado_Avalanche_1 = 1.0
# match_Tampa_Bay_Lightning_Columbus_Blue_Jackets_1 = 1.0
# match_Tampa_Bay_Lightning_Columbus_Blue_Jackets_10 = 1.0
# match_Tampa_Bay_Lightning_Dallas_Stars_1 = 1.0
# match_Tampa_Bay_Lightning_Detroit_Red_Wings_1 = 1.0
# match_Tampa_Bay_Lightning_Detroit_Red_Wings_100 = 1.0
# match_Tampa_Bay_Lightning_Edmonton_Oilers_1 = 1.0
# match_Tampa_Bay_Lightning_Florida_Panthers_1 = 1.0
# match_Tampa_Bay_Lightning_Florida_Panthers_100 = 1.0
# match_Tampa_Bay_Lightning_Los_Angeles_Kings_0 = 1.0
# match_Tampa_Bay_Lightning_Minnesota_Wild_0 = 1.0
# match_Tampa_Bay_Lightning_Montreal_Canadiens_100 = 1.0
# match_Tampa_Bay_Lightning_Montreal_Canadiens_14 = 1.0
# match_Tampa_Bay_Lightning_Nashville_Predators_100 = 1.0
# match_Tampa_Bay_Lightning_New_Jersey_Devils_10 = 1.0
# match_Tampa_Bay_Lightning_New_Jersey_Devils_14 = 1.0
# match_Tampa_Bay_Lightning_New_York_Islanders_100 = 1.0
# match_Tampa_Bay_Lightning_New_York_Islanders_14 = 1.0
# match_Tampa_Bay_Lightning_New_York_Rangers_10 = 1.0
# match_Tampa_Bay_Lightning_New_York_Rangers_14 = 1.0
# match_Tampa_Bay_Lightning_Ottawa_Senators_100 = 1.0
# match_Tampa_Bay_Lightning_Ottawa_Senators_14 = 1.0
# match_Tampa_Bay_Lightning_Philadelphia_Flyers_100 = 1.0
# match_Tampa_Bay_Lightning_Philadelphia_Flyers_9 = 1.0
# match_Tampa_Bay_Lightning_Pittsburgh_Penguins_100 = 1.0
# match_Tampa_Bay_Lightning_Pittsburgh_Penguins_14 = 1.0
# match_Tampa_Bay_Lightning_San_Jose_Sharks_0 = 1.0
# match_Tampa_Bay_Lightning_Seattle_Kraken_100 = 1.0
# match_Tampa_Bay_Lightning_St._Louis_Blues_0 = 1.0
# match_Tampa_Bay_Lightning_Toronto_Maple_Leafs_1 = 1.0
# match_Tampa_Bay_Lightning_Toronto_Maple_Leafs_100 = 1.0
# match_Tampa_Bay_Lightning_Vancouver_Canucks_0 = 1.0
# match_Tampa_Bay_Lightning_Vegas_Golden_Knights_1 = 1.0
# match_Tampa_Bay_Lightning_Washington_Capitals_1 = 1.0
# match_Tampa_Bay_Lightning_Washington_Capitals_100 = 1.0
# match_Tampa_Bay_Lightning_Winnipeg_Jets_1 = 1.0
# match_Toronto_Maple_Leafs_Anaheim_Ducks_0 = 1.0
# match_Toronto_Maple_Leafs_Arizona_Coyotes_0 = 1.0
# match_Toronto_Maple_Leafs_Boston_Bruins_1 = 1.0
# match_Toronto_Maple_Leafs_Boston_Bruins_10 = 1.0
# match_Toronto_Maple_Leafs_Buffalo_Sabres_1 = 1.0
# match_Toronto_Maple_Leafs_Buffalo_Sabres_10 = 1.0
# match_Toronto_Maple_Leafs_Calgary_Flames_1 = 1.0
# match_Toronto_Maple_Leafs_Carolina_Hurricanes_1 = 1.0
# match_Toronto_Maple_Leafs_Carolina_Hurricanes_100 = 1.0
# match_Toronto_Maple_Leafs_Chicago_Blackhawks_1 = 1.0
# match_Toronto_Maple_Leafs_Colorado_Avalanche_0 = 1.0
# match_Toronto_Maple_Leafs_Columbus_Blue_Jackets_1 = 1.0
# match_Toronto_Maple_Leafs_Columbus_Blue_Jackets_100 = 1.0
# match_Toronto_Maple_Leafs_Dallas_Stars_1 = 1.0
# match_Toronto_Maple_Leafs_Detroit_Red_Wings_1 = 1.0
# match_Toronto_Maple_Leafs_Detroit_Red_Wings_100 = 1.0
# match_Toronto_Maple_Leafs_Edmonton_Oilers_0 = 1.0
# match_Toronto_Maple_Leafs_Florida_Panthers_1 = 1.0
# match_Toronto_Maple_Leafs_Florida_Panthers_100 = 1.0
# match_Toronto_Maple_Leafs_Los_Angeles_Kings_1 = 1.0
# match_Toronto_Maple_Leafs_Minnesota_Wild_0 = 1.0
# match_Toronto_Maple_Leafs_Montreal_Canadiens_100 = 1.0
# match_Toronto_Maple_Leafs_Montreal_Canadiens_14 = 1.0
# match_Toronto_Maple_Leafs_Nashville_Predators_100 = 1.0
# match_Toronto_Maple_Leafs_New_Jersey_Devils_14 = 1.0
# match_Toronto_Maple_Leafs_New_Jersey_Devils_9 = 1.0
# match_Toronto_Maple_Leafs_New_York_Islanders_100 = 1.0
# match_Toronto_Maple_Leafs_New_York_Islanders_9 = 1.0
# match_Toronto_Maple_Leafs_New_York_Rangers_100 = 1.0
# match_Toronto_Maple_Leafs_New_York_Rangers_14 = 1.0
# match_Toronto_Maple_Leafs_Ottawa_Senators_100 = 1.0
# match_Toronto_Maple_Leafs_Ottawa_Senators_9 = 1.0
# match_Toronto_Maple_Leafs_Philadelphia_Flyers_1 = 1.0
# match_Toronto_Maple_Leafs_Philadelphia_Flyers_14 = 1.0
# match_Toronto_Maple_Leafs_Pittsburgh_Penguins_14 = 1.0
# match_Toronto_Maple_Leafs_Pittsburgh_Penguins_9 = 1.0
# match_Toronto_Maple_Leafs_San_Jose_Sharks_100 = 1.0
# match_Toronto_Maple_Leafs_Seattle_Kraken_10 = 1.0
# match_Toronto_Maple_Leafs_St._Louis_Blues_100 = 1.0
# match_Toronto_Maple_Leafs_Tampa_Bay_Lightning_10 = 1.0
# match_Toronto_Maple_Leafs_Tampa_Bay_Lightning_14 = 1.0
# match_Toronto_Maple_Leafs_Vancouver_Canucks_0 = 1.0
# match_Toronto_Maple_Leafs_Vegas_Golden_Knights_1 = 1.0
# match_Toronto_Maple_Leafs_Washington_Capitals_1 = 1.0
# match_Toronto_Maple_Leafs_Washington_Capitals_100 = 1.0
# match_Toronto_Maple_Leafs_Winnipeg_Jets_1 = 1.0
# match_Vancouver_Canucks_Anaheim_Ducks_1 = 1.0
# match_Vancouver_Canucks_Anaheim_Ducks_100 = 1.0
# match_Vancouver_Canucks_Arizona_Coyotes_1 = 1.0
# match_Vancouver_Canucks_Arizona_Coyotes_100 = 1.0
# match_Vancouver_Canucks_Boston_Bruins_0 = 1.0
# match_Vancouver_Canucks_Buffalo_Sabres_0 = 1.0
# match_Vancouver_Canucks_Calgary_Flames_1 = 1.0
# match_Vancouver_Canucks_Calgary_Flames_100 = 1.0
# match_Vancouver_Canucks_Carolina_Hurricanes_0 = 1.0
# match_Vancouver_Canucks_Chicago_Blackhawks_1 = 1.0
# match_Vancouver_Canucks_Chicago_Blackhawks_10 = 1.0
# match_Vancouver_Canucks_Colorado_Avalanche_1 = 1.0
# match_Vancouver_Canucks_Colorado_Avalanche_100 = 1.0
# match_Vancouver_Canucks_Columbus_Blue_Jackets_1 = 1.0
# match_Vancouver_Canucks_Dallas_Stars_1 = 1.0
# match_Vancouver_Canucks_Dallas_Stars_10 = 1.0
# match_Vancouver_Canucks_Detroit_Red_Wings_0 = 1.0
# match_Vancouver_Canucks_Edmonton_Oilers_1 = 1.0
# match_Vancouver_Canucks_Edmonton_Oilers_10 = 1.0
# match_Vancouver_Canucks_Florida_Panthers_0 = 1.0
# match_Vancouver_Canucks_Los_Angeles_Kings_1 = 1.0
# match_Vancouver_Canucks_Los_Angeles_Kings_100 = 1.0
# match_Vancouver_Canucks_Minnesota_Wild_100 = 1.0
# match_Vancouver_Canucks_Minnesota_Wild_14 = 1.0
# match_Vancouver_Canucks_Montreal_Canadiens_100 = 1.0
# match_Vancouver_Canucks_Nashville_Predators_10 = 1.0
# match_Vancouver_Canucks_Nashville_Predators_14 = 1.0
# match_Vancouver_Canucks_New_Jersey_Devils_10 = 1.0
# match_Vancouver_Canucks_New_York_Islanders_100 = 1.0
# match_Vancouver_Canucks_New_York_Rangers_10 = 1.0
# match_Vancouver_Canucks_Ottawa_Senators_100 = 1.0
# match_Vancouver_Canucks_Philadelphia_Flyers_100 = 1.0
# match_Vancouver_Canucks_Pittsburgh_Penguins_100 = 1.0
# match_Vancouver_Canucks_San_Jose_Sharks_14 = 1.0
# match_Vancouver_Canucks_San_Jose_Sharks_8 = 1.0
# match_Vancouver_Canucks_Seattle_Kraken_100 = 1.0
# match_Vancouver_Canucks_Seattle_Kraken_14 = 1.0
# match_Vancouver_Canucks_St._Louis_Blues_14 = 1.0
# match_Vancouver_Canucks_St._Louis_Blues_8 = 1.0
# match_Vancouver_Canucks_Tampa_Bay_Lightning_100 = 1.0
# match_Vancouver_Canucks_Toronto_Maple_Leafs_100 = 1.0
# match_Vancouver_Canucks_Vegas_Golden_Knights_1 = 1.0
# match_Vancouver_Canucks_Vegas_Golden_Knights_100 = 1.0
# match_Vancouver_Canucks_Washington_Capitals_1 = 1.0
# match_Vancouver_Canucks_Winnipeg_Jets_1 = 1.0
# match_Vancouver_Canucks_Winnipeg_Jets_100 = 1.0
# match_Vegas_Golden_Knights_Anaheim_Ducks_1 = 1.0
# match_Vegas_Golden_Knights_Anaheim_Ducks_100 = 1.0
# match_Vegas_Golden_Knights_Arizona_Coyotes_1 = 1.0
# match_Vegas_Golden_Knights_Arizona_Coyotes_10 = 1.0
# match_Vegas_Golden_Knights_Boston_Bruins_1 = 1.0
# match_Vegas_Golden_Knights_Buffalo_Sabres_0 = 1.0
# match_Vegas_Golden_Knights_Calgary_Flames_1 = 1.0
# match_Vegas_Golden_Knights_Calgary_Flames_10 = 1.0
# match_Vegas_Golden_Knights_Carolina_Hurricanes_0 = 1.0
# match_Vegas_Golden_Knights_Chicago_Blackhawks_1 = 1.0
# match_Vegas_Golden_Knights_Chicago_Blackhawks_10 = 1.0
# match_Vegas_Golden_Knights_Colorado_Avalanche_1 = 1.0
# match_Vegas_Golden_Knights_Colorado_Avalanche_100 = 1.0
# match_Vegas_Golden_Knights_Columbus_Blue_Jackets_1 = 1.0
# match_Vegas_Golden_Knights_Dallas_Stars_1 = 1.0
# match_Vegas_Golden_Knights_Dallas_Stars_10 = 1.0
# match_Vegas_Golden_Knights_Detroit_Red_Wings_1 = 1.0
# match_Vegas_Golden_Knights_Edmonton_Oilers_1 = 1.0
# match_Vegas_Golden_Knights_Edmonton_Oilers_100 = 1.0
# match_Vegas_Golden_Knights_Florida_Panthers_1 = 1.0
# match_Vegas_Golden_Knights_Los_Angeles_Kings_1 = 1.0
# match_Vegas_Golden_Knights_Los_Angeles_Kings_100 = 1.0
# match_Vegas_Golden_Knights_Minnesota_Wild_100 = 1.0
# match_Vegas_Golden_Knights_Minnesota_Wild_14 = 1.0
# match_Vegas_Golden_Knights_Montreal_Canadiens_100 = 1.0
# match_Vegas_Golden_Knights_Nashville_Predators_10 = 1.0
# match_Vegas_Golden_Knights_Nashville_Predators_14 = 1.0
# match_Vegas_Golden_Knights_New_Jersey_Devils_10 = 1.0
# match_Vegas_Golden_Knights_New_York_Islanders_0 = 1.0
# match_Vegas_Golden_Knights_New_York_Rangers_10 = 1.0
# match_Vegas_Golden_Knights_Ottawa_Senators_0 = 1.0
# match_Vegas_Golden_Knights_Philadelphia_Flyers_100 = 1.0
# match_Vegas_Golden_Knights_Pittsburgh_Penguins_100 = 1.0
# match_Vegas_Golden_Knights_San_Jose_Sharks_100 = 1.0
# match_Vegas_Golden_Knights_San_Jose_Sharks_14 = 1.0
# match_Vegas_Golden_Knights_Seattle_Kraken_100 = 1.0
# match_Vegas_Golden_Knights_Seattle_Kraken_9 = 1.0
# match_Vegas_Golden_Knights_St._Louis_Blues_100 = 1.0
# match_Vegas_Golden_Knights_St._Louis_Blues_14 = 1.0
# match_Vegas_Golden_Knights_Tampa_Bay_Lightning_100 = 1.0
# match_Vegas_Golden_Knights_Toronto_Maple_Leafs_0 = 1.0
# match_Vegas_Golden_Knights_Vancouver_Canucks_100 = 1.0
# match_Vegas_Golden_Knights_Vancouver_Canucks_14 = 1.0
# match_Vegas_Golden_Knights_Washington_Capitals_0 = 1.0
# match_Vegas_Golden_Knights_Winnipeg_Jets_1 = 1.0
# match_Vegas_Golden_Knights_Winnipeg_Jets_10 = 1.0
# match_Washington_Capitals_Anaheim_Ducks_1 = 1.0
# match_Washington_Capitals_Arizona_Coyotes_0 = 1.0
# match_Washington_Capitals_Boston_Bruins_1 = 1.0
# match_Washington_Capitals_Boston_Bruins_100 = 1.0
# match_Washington_Capitals_Buffalo_Sabres_1 = 1.0
# match_Washington_Capitals_Buffalo_Sabres_100 = 1.0
# match_Washington_Capitals_Calgary_Flames_0 = 1.0
# match_Washington_Capitals_Carolina_Hurricanes_1 = 1.0
# match_Washington_Capitals_Carolina_Hurricanes_100 = 1.0
# match_Washington_Capitals_Chicago_Blackhawks_1 = 1.0
# match_Washington_Capitals_Colorado_Avalanche_1 = 1.0
# match_Washington_Capitals_Columbus_Blue_Jackets_1 = 1.0
# match_Washington_Capitals_Columbus_Blue_Jackets_10 = 1.0
# match_Washington_Capitals_Dallas_Stars_1 = 1.0
# match_Washington_Capitals_Detroit_Red_Wings_1 = 1.0
# match_Washington_Capitals_Detroit_Red_Wings_100 = 1.0
# match_Washington_Capitals_Edmonton_Oilers_0 = 1.0
# match_Washington_Capitals_Florida_Panthers_1 = 1.0
# match_Washington_Capitals_Florida_Panthers_100 = 1.0
# match_Washington_Capitals_Los_Angeles_Kings_0 = 1.0
# match_Washington_Capitals_Minnesota_Wild_100 = 1.0
# match_Washington_Capitals_Montreal_Canadiens_14 = 1.0
# match_Washington_Capitals_Montreal_Canadiens_9 = 1.0
# match_Washington_Capitals_Nashville_Predators_0 = 1.0
# match_Washington_Capitals_New_Jersey_Devils_100 = 1.0
# match_Washington_Capitals_New_Jersey_Devils_14 = 1.0
# match_Washington_Capitals_New_York_Islanders_0 = 1.0
# match_Washington_Capitals_New_York_Islanders_14 = 1.0
# match_Washington_Capitals_New_York_Rangers_0 = 1.0
# match_Washington_Capitals_New_York_Rangers_14 = 1.0
# match_Washington_Capitals_Ottawa_Senators_1 = 1.0
# match_Washington_Capitals_Ottawa_Senators_14 = 1.0
# match_Washington_Capitals_Philadelphia_Flyers_10 = 1.0
# match_Washington_Capitals_Philadelphia_Flyers_14 = 1.0
# match_Washington_Capitals_Pittsburgh_Penguins_14 = 1.0
# match_Washington_Capitals_Pittsburgh_Penguins_8 = 1.0
# match_Washington_Capitals_San_Jose_Sharks_10 = 1.0
# match_Washington_Capitals_Seattle_Kraken_100 = 1.0
# match_Washington_Capitals_St._Louis_Blues_0 = 1.0
# match_Washington_Capitals_Tampa_Bay_Lightning_100 = 1.0
# match_Washington_Capitals_Tampa_Bay_Lightning_8 = 1.0
# match_Washington_Capitals_Toronto_Maple_Leafs_10 = 1.0
# match_Washington_Capitals_Toronto_Maple_Leafs_14 = 1.0
# match_Washington_Capitals_Vancouver_Canucks_100 = 1.0
# match_Washington_Capitals_Vegas_Golden_Knights_0 = 1.0
# match_Washington_Capitals_Winnipeg_Jets_0 = 1.0
# match_Winnipeg_Jets_Anaheim_Ducks_1 = 1.0
# match_Winnipeg_Jets_Anaheim_Ducks_100 = 1.0
# match_Winnipeg_Jets_Arizona_Coyotes_1 = 1.0
# match_Winnipeg_Jets_Arizona_Coyotes_100 = 1.0
# match_Winnipeg_Jets_Boston_Bruins_0 = 1.0
# match_Winnipeg_Jets_Buffalo_Sabres_0 = 1.0
# match_Winnipeg_Jets_Calgary_Flames_1 = 1.0
# match_Winnipeg_Jets_Calgary_Flames_10 = 1.0
# match_Winnipeg_Jets_Carolina_Hurricanes_0 = 1.0
# match_Winnipeg_Jets_Chicago_Blackhawks_1 = 1.0
# match_Winnipeg_Jets_Chicago_Blackhawks_100 = 1.0
# match_Winnipeg_Jets_Colorado_Avalanche_1 = 1.0
# match_Winnipeg_Jets_Colorado_Avalanche_100 = 1.0
# match_Winnipeg_Jets_Columbus_Blue_Jackets_1 = 1.0
# match_Winnipeg_Jets_Dallas_Stars_1 = 1.0
# match_Winnipeg_Jets_Dallas_Stars_100 = 1.0
# match_Winnipeg_Jets_Detroit_Red_Wings_0 = 1.0
# match_Winnipeg_Jets_Edmonton_Oilers_1 = 1.0
# match_Winnipeg_Jets_Edmonton_Oilers_10 = 1.0
# match_Winnipeg_Jets_Florida_Panthers_1 = 1.0
# match_Winnipeg_Jets_Los_Angeles_Kings_1 = 1.0
# match_Winnipeg_Jets_Los_Angeles_Kings_10 = 1.0
# match_Winnipeg_Jets_Minnesota_Wild_0 = 1.0
# match_Winnipeg_Jets_Minnesota_Wild_14 = 1.0
# match_Winnipeg_Jets_Montreal_Canadiens_10 = 1.0
# match_Winnipeg_Jets_Nashville_Predators_100 = 1.0
# match_Winnipeg_Jets_Nashville_Predators_9 = 1.0
# match_Winnipeg_Jets_New_Jersey_Devils_100 = 1.0
# match_Winnipeg_Jets_New_York_Islanders_0 = 1.0
# match_Winnipeg_Jets_New_York_Rangers_0 = 1.0
# match_Winnipeg_Jets_Ottawa_Senators_0 = 1.0
# match_Winnipeg_Jets_Philadelphia_Flyers_100 = 1.0
# match_Winnipeg_Jets_Pittsburgh_Penguins_100 = 1.0
# match_Winnipeg_Jets_San_Jose_Sharks_10 = 1.0
# match_Winnipeg_Jets_San_Jose_Sharks_14 = 1.0
# match_Winnipeg_Jets_Seattle_Kraken_100 = 1.0
# match_Winnipeg_Jets_Seattle_Kraken_8 = 1.0
# match_Winnipeg_Jets_St._Louis_Blues_100 = 1.0
# match_Winnipeg_Jets_St._Louis_Blues_14 = 1.0
# match_Winnipeg_Jets_Tampa_Bay_Lightning_0 = 1.0
# match_Winnipeg_Jets_Toronto_Maple_Leafs_0 = 1.0
# match_Winnipeg_Jets_Vancouver_Canucks_100 = 1.0
# match_Winnipeg_Jets_Vancouver_Canucks_14 = 1.0
# match_Winnipeg_Jets_Vegas_Golden_Knights_10 = 1.0
# match_Winnipeg_Jets_Vegas_Golden_Knights_14 = 1.0
# match_Winnipeg_Jets_Washington_Capitals_10 = 1.0

# %% [markdown]
# How to interpret the results:
#
# match_Anaheim_Ducks_Arizona_Coyotes_0 = 1.0
#
# This means the teams playing are Anaheim_Ducks and Arizona_Coyotes. The 0 is the day index (in this case it is the first day) and the 1.0 means that the game is good to be scheduled

# %% [markdown]
# ## Improvements
#
# Ideally I wanted to put in team preferences into the later optimization problem. Unfortunately I had a lot of trouble implementing that.
#
# Additionally I have rest day constraints but no time period constraint on how many days until all the games have to be played.
#
# Lastly I am just using random distances to focus on the optimization problem. Next steps would include getting the actual distances.
